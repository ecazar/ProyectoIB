# %%
from mceclib.preprocessing import *
from mceclib.jaccard import *
from mceclib.tfidf import *
from mceclib.bm25 import *
from mceclib.evaluate import *

# %%
import gzip
import json
import pandas as pd

path = './data/'
with gzip.open(path + 'corpus.jsonl.gz', 'rt', encoding='utf-8') as file:
    lines = file.readlines()
data = [json.loads(line) for line in lines]
corpus = pd.DataFrame(data)
corpus = corpus[['_id','text']]

# %%
type(corpus)
# Out:
# pandas.core.frame.DataFrame

# %%
corpus_text = corpus["text"]

# %%
corpus_text
# Out:
# 0       You don’t have to be vegetarian to be green. M...
# 1       Being vegetarian helps the environment  Becomi...
# 2       The key to good health is a balanced diet, not...
# 3       It is immoral to kill animals  As evolved huma...
# 4       There is a great moral difference between huma...
#                               ...
# 8669    Stories about ridiculous administration costs ...
# 8670    We need to address the causes of poverty rathe...
# 8671    Sponsorship is often more about the intentions...
# 8672    Sponsorship is an inefficient way of giving to...
# 8673    Many of the organisations that run child spons...
# Name: text, Length: 8674, dtype: object

# %%
type(corpus_text)
# Out:
# pandas.core.series.Series

# %%
corpus_clean = corpus_text.apply(preprocessing2text)

# %%
corpus_clean
# Out:
# 0       vegetarian green mani special environ creat li...
# 1       vegetarian help environ becom vegetarian envir...
# 2       key good health balanc diet meat fishfre diet ...
# 3       immor kill anim evolv human be moral duti infl...
# 4       great moral differ human anim unlik anim human...
#                               ...
# 8669    stori ridicul administr cost rare often untru ...
# 8670    need address caus poverti rather treat symptom...
# 8671    sponsorship often intent donor rather need poo...
# 8672    sponsorship ineffici way give chariti sponsor ...
# 8673    mani organis run child sponsorship scheme dedi...
# Name: text, Length: 8674, dtype: object

# %%
type(corpus_clean)
# Out:
# pandas.core.series.Series

# %%
corpus_clean_tokenized = corpus_clean.apply(tokenize_text)

# %%
corpus_clean_tokenized
# Out:
# 0       [vegetarian, green, mani, special, environ, cr...
# 1       [vegetarian, help, environ, becom, vegetarian,...
# 2       [key, good, health, balanc, diet, meat, fishfr...
# 3       [immor, kill, anim, evolv, human, be, moral, d...
# 4       [great, moral, differ, human, anim, unlik, ani...
#                               ...
# 8669    [stori, ridicul, administr, cost, rare, often,...
# 8670    [need, address, caus, poverti, rather, treat, ...
# 8671    [sponsorship, often, intent, donor, rather, ne...
# 8672    [sponsorship, ineffici, way, give, chariti, sp...
# 8673    [mani, organis, run, child, sponsorship, schem...
# Name: text, Length: 8674, dtype: object

# %%
type(corpus_clean_tokenized)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Jacard
# * corpus_clean_tokenized
# * corpus_original

# %%
query_jacard = "harmful"

# %%
result_jacard = search_jaccard(query_jacard, corpus_clean_tokenized, corpus)

# %%
result_jacard
# Out:
#                                          id  \
# 0         training-economy-befhwimsc-pro03b
# 1         training-religion-msfhbmoi-con03b
# 2          test-environment-assgbatj-pro05b
# 3             test-science-eassgbatj-pro05b
# 4     validation-education-egpsthwtj-pro02b
# ...                                     ...
# 8669   validation-society-gfhbcimrst-con03b
# 8670   validation-society-gfhbcimrst-con01b
# 8671   validation-society-gfhbcimrst-con02a
# 8672   validation-society-gfhbcimrst-con05a
# 8673   validation-society-gfhbcimrst-con04a
#
#                                                    text    scores
# 0     It is equally likely that money is a significa...  0.100000
# 1     If marriage’s main function is to protect agai...  0.071429
# 2     There is a moral difference between harm for t...  0.062500
# 3     There is a moral difference between harm for t...  0.062500
# 4     When homework does take up time in class it is...  0.062500
# ...                                                 ...       ...
# 8669  Whilst the Indian government may have policies...  0.000000
# 8670  Our policy provides far more than these existi...  0.000000
# 8671  Commodifying women.  Surely providing a financ...  0.000000
# 8672  Autonomy (Please note that this argument canno...  0.000000
# 8673  Financial incentives do not break down cultura...  0.000000
#
# [8674 rows x 3 columns]

# %%
simple_result_jacard = simple_search_jaccard(query_jacard, corpus_clean_tokenized)
simple_result_jacard
# Out:
# [(np.int64(3908), np.float64(0.1)),
#  (np.int64(7416), np.float64(0.07142857142857142)),
#  (np.int64(20), np.float64(0.0625)),
#  (np.int64(8320), np.float64(0.0625)),
#  (np.int64(2526), np.float64(0.0625))]

# %% [markdown]
# # TF-IDF
# * corpus_clean
# * corpus_original

# %%
query_tfidf = "harmful"

# %%
matriz_tfidf, vectorizer = build_tfidf(corpus_clean)

# %%
result_tfidf = search_tdifd(query_tfidf, vectorizer, matriz_tfidf, corpus)

# %%
result_tfidf
# Out:
#                                                  id  \
# 0                  test-environment-assgbatj-pro05b
# 1                     test-science-eassgbatj-pro05b
# 2                    training-law-ucgllghwbg-con01b
# 3                 training-health-ahgshbcsbl-pro01b
# 4     training-free-speech-debate-nshbbhnpsb-pro03a
# ...                                             ...
# 8669           validation-society-gfhbcimrst-con03b
# 8670           validation-society-gfhbcimrst-con01b
# 8671           validation-society-gfhbcimrst-con02a
# 8672           validation-society-gfhbcimrst-con05a
# 8673           validation-society-gfhbcimrst-con04a
#
#                                                    text    scores
# 0     There is a moral difference between harm for t...  0.433718
# 1     There is a moral difference between harm for t...  0.433718
# 2     Gambling is a harmful activity and could have ...  0.413519
# 3     While individual liberty is an important good,...  0.388738
# 4     People have a right to blaspheme  In the laws ...  0.381923
# ...                                                 ...       ...
# 8669  Whilst the Indian government may have policies...  0.000000
# 8670  Our policy provides far more than these existi...  0.000000
# 8671  Commodifying women.  Surely providing a financ...  0.000000
# 8672  Autonomy (Please note that this argument canno...  0.000000
# 8673  Financial incentives do not break down cultura...  0.000000
#
# [8674 rows x 3 columns]

# %%
simple_result_tfidf = simple_search_tdifd(query_tfidf, vectorizer, matriz_tfidf)
simple_result_tfidf
# Out:
# [(np.int64(2526), np.float64(0.433718255790206)),
#  (np.int64(20), np.float64(0.433718255790206)),
#  (np.int64(5875), np.float64(0.41351934108835353)),
#  (np.int64(3147), np.float64(0.38873786624641904)),
#  (np.int64(3421), np.float64(0.3819232115506393))]

# %% [markdown]
# # BM25
# * corpus_clean_tokenized
# * corpus_original

# %%
query_bm25 = "daughter spiderman"

# %%
bm25_model = build_bm25_model(corpus_clean_tokenized)

# %%
result_bm25 = search_bm25(query_bm25, bm25_model, corpus)

# %%
result_bm25
# Out:
#                                                 id  \
# 0              training-society-gfyhbprcsao-pro01a
# 1      validation-digital-freedoms-phbphnrp-con02a
# 2     training-digital-freedoms-phbplpfsbop-pro03a
# 3           training-philosophy-lsgsgfhbpsb-con01b
# 4         test-free-speech-debate-radhbsshr-con04b
# ...                                            ...
# 8669          validation-society-gfhbcimrst-con03b
# 8670          validation-society-gihbsosbcg-con02a
# 8671          validation-society-gfhbcimrst-con02a
# 8672          validation-society-gfhbcimrst-con05a
# 8673            training-society-negsimhwso-pro01a
#
#                                                    text    scores
# 0     The one child policy skews gender demographics...  9.938928
# 1     Fixating on personal lives results in infringi...  9.019144
# 2     No clear dividing line between public and priv...  8.761588
# 3     It is for the individuals to decide whether th...  7.415137
# 4     The painting should remain hanging as a remind...  7.369124
# ...                                                 ...       ...
# 8669  Whilst the Indian government may have policies...  0.000000
# 8670  This policy breaks down important inter-govern...  0.000000
# 8671  Commodifying women.  Surely providing a financ...  0.000000
# 8672  Autonomy (Please note that this argument canno...  0.000000
# 8673  Minorities deserve linguistic rights  Everyone...  0.000000
#
# [8674 rows x 3 columns]

# %%
simple_result_bm25 = simple_search_bm25(query_bm25, bm25_model)
simple_result_bm25
# Out:
# [(np.int64(7627), np.float64(9.938927915397242)),
#  (np.int64(8536), np.float64(9.019144377771683)),
#  (np.int64(7275), np.float64(8.76158789849452)),
#  (np.int64(5379), np.float64(7.415137149987788)),
#  (np.int64(395), np.float64(7.369124281079814))]

# %% [markdown]
# ---

# %% [markdown]
# # Qrels

# %%
with gzip.open(path + 'train.jsonl.gz', 'rt', encoding='utf-8') as file:
    lines = file.readlines()
queriesdt = [json.loads(line) for line in lines]

qrels = pd.DataFrame(queriesdt)
qrels = qrels[['_id','text', 'query']].head(100)
qrels
# Out:
#                                   _id  \
# 0   test-environment-aeghhgwpe-pro02b
# 1   test-environment-aeghhgwpe-pro02b
# 2   test-environment-aeghhgwpe-pro02b
# 3   test-environment-aeghhgwpe-pro02a
# 4   test-environment-aeghhgwpe-pro02a
# ..                                ...
# 95   test-environment-assgbatj-con01a
# 96   test-environment-assgbatj-con04b
# 97   test-environment-assgbatj-con04b
# 98   test-environment-assgbatj-con04b
# 99   test-environment-assgbatj-con02b
#
#                                                  text  \
# 0   You don’t have to be vegetarian to be green. M...
# 1   You don’t have to be vegetarian to be green. M...
# 2   You don’t have to be vegetarian to be green. M...
# 3   Being vegetarian helps the environment  Becomi...
# 4   Being vegetarian helps the environment  Becomi...
# ..                                                ...
# 95  Animals don’t have human rights  Humans have l...
# 96  Not every country has laws like the EU or the ...
# 97  Not every country has laws like the EU or the ...
# 98  Not every country has laws like the EU or the ...
# 99  Many of these drugs are “me too” drugs – ones ...
#
#                                                 query
# 0           is it better to be a vegan or vegetarian?
# 1                     is meat environmentally harmful
# 2                         is it good to be vegetarian
# 3                how does meat affect the environment
# 4   what is the most important driver for deforest...
# ..                                                ...
# 95                                 are humans animals
# 96                    is it bad to use animal testing
# 97                     can the us ban animal testing?
# 98                       should i ban testing animals
# 99                     should you ban testing animals
#
# [100 rows x 3 columns]

# %% [markdown]
# Diccionario de qrels

# %%
qrels_dict= qrels.groupby('query')['_id'].apply(list).to_dict()
qrels_dict
# Out:
# {'adn natural selection definition in the world': ['test-environment-aeghhgwpe-con03a'],
#  'animal tests': ['test-environment-assgbatj-con03b'],
#  'are humans animals': ['test-environment-assgbatj-con01a'],
#  'are humans omnivores': ['test-environment-aeghhgwpe-con01b'],
#  'are meats bad for you': ['test-environment-aeghhgwpe-pro03a'],
#  'are zoonotic diseases transmitted by animal products': ['test-environment-aeghhgwpe-pro04b'],
#  'benefits of vegetarian diet': ['test-environment-aeghhgwpe-pro03a'],
#  'can a scientist test animals': ['test-environment-assgbatj-con05b'],
#  'can the government ban animal testing': ['test-environment-assgbatj-con05a'],
#  'can the us ban animal testing?': ['test-environment-assgbatj-con04b'],
#  'can vegetarians eat a lot of iron': ['test-environment-aeghhgwpe-con02b'],
#  'can vegetarians eat cereal': ['test-environment-aeghhgwpe-con02b'],
#  'can vegetarians have iron': ['test-environment-aeghhgwpe-con02b'],
#  'can we ban animal testing': ['test-environment-assgbatj-pro04a'],
#  'can you use animal testing?': ['test-environment-assgbatj-pro05a'],
#  'charles darwin on the origin of species by means of natural selection': ['test-environment-aeghhgwpe-con03a'],
#  'could we ban animal testing': ['test-environment-assgbatj-pro03b'],
#  'deforestation impacts animals environment': ['test-environment-aeghhgwpe-pro02a'],
#  'do animals need to be slaughtered to have life': ['test-environment-aeghhgwpe-pro01a'],
#  'does animal testing are necessary': ['test-environment-assgbatj-pro03a'],
#  'does being a vegetarian cause you to feel depressed and tired': ['test-environment-aeghhgwpe-con02a'],
#  'does it have to be cruel to feed animals': ['test-environment-aeghhgwpe-pro01b'],
#  'does science ban animal testing': ['test-environment-assgbatj-pro05a'],
#  'does the ban on testing animals come about': ['test-environment-assgbatj-pro04a'],
#  'how can a healthy diet combat food poisoning': ['test-environment-aeghhgwpe-pro04b'],
#  'how can we stop animal testing': ['test-environment-assgbatj-con01b'],
#  'how cruel are animal slaughter': ['test-environment-aeghhgwpe-pro01a'],
#  'how does meat affect the environment': ['test-environment-aeghhgwpe-pro02a'],
#  'how does the food chain prevent food poisoning': ['test-environment-aeghhgwpe-pro04b'],
#  'how is meat bad for your body': ['test-environment-aeghhgwpe-pro03a'],
#  'how many drugs are tested in the uk every year': ['test-environment-assgbatj-con02a'],
#  'how many people die from animal testing': ['test-environment-assgbatj-con02a'],
#  'how much protein is in raw meat': ['test-environment-aeghhgwpe-pro03b'],
#  'how to ban animal testing': ['test-environment-assgbatj-con05b'],
#  'how to judge battery farms morally': ['test-environment-aeghhgwpe-con03b'],
#  'is animal research dangerous': ['test-environment-assgbatj-pro02a'],
#  'is it bad to use animal testing': ['test-environment-assgbatj-con04b'],
#  'is it better to be a vegan or vegetarian?': ['test-environment-aeghhgwpe-pro02b'],
#  'is it good to be vegetarian': ['test-environment-aeghhgwpe-pro02b'],
#  'is it natural for humans to eat meat': ['test-environment-aeghhgwpe-con01a'],
#  'is it necessary to ban animal testing': ['test-environment-assgbatj-con01a'],
#  'is meat environmentally harmful': ['test-environment-aeghhgwpe-pro02b'],
#  'is testing animals ok': ['test-environment-assgbatj-con05b'],
#  'should a drug be used in research on humans': ['test-environment-assgbatj-con03b'],
#  'should animal research be banned': ['test-environment-assgbatj-pro03a'],
#  'should i ban testing animals': ['test-environment-assgbatj-con04b'],
#  'should research cause severe damage': ['test-environment-assgbatj-pro02a'],
#  'should we ban animal testing': ['test-environment-assgbatj-con01b'],
#  'should you ban testing animals': ['test-environment-assgbatj-con02b'],
#  'what are common food poisonings in meat': ['test-environment-aeghhgwpe-pro04a'],
#  'what are the symptoms of being a vegan': ['test-environment-aeghhgwpe-con02a'],
#  'what do you eat to be vegetarian': ['test-environment-aeghhgwpe-pro03b'],
#  'what does animal testing do to animals': ['test-environment-assgbatj-pro02a'],
#  'what does animal testing mean': ['test-environment-assgbatj-pro04b'],
#  'what does the interest of the animal mean': ['test-environment-assgbatj-pro02b'],
#  'what evolved the human body as an omnivore': ['test-environment-aeghhgwpe-con01b'],
#  'what foods can cause food poisoning': ['test-environment-aeghhgwpe-pro04a'],
#  'what foods have e coli': ['test-environment-aeghhgwpe-pro04a'],
#  'what is a ban for animals': ['test-environment-assgbatj-con04a'],
#  'what is the ban on animal testing': ['test-environment-assgbatj-pro04a'],
#  'what is the difference between animal testing and health care': ['test-environment-assgbatj-pro05b'],
#  'what is the difference between harm for the sake of harming an animal and harm in order to save lives?': ['test-environment-assgbatj-pro05b'],
#  'what is the difference between lifesaving drugs and animal testing': ['test-environment-assgbatj-pro05b'],
#  'what is the healthy diet of the vegetarian': ['test-environment-aeghhgwpe-pro03b'],
#  'what is the interest of the animal?': ['test-environment-assgbatj-pro02b'],
#  'what is the most important driver for deforestation': ['test-environment-aeghhgwpe-pro02a'],
#  'what is the right of a human to not be harmed based on': ['test-environment-assgbatj-pro01b'],
#  'what is vegetarian symptoms': ['test-environment-aeghhgwpe-con02a'],
#  'what kind of drugs can you give a human': ['test-environment-assgbatj-con03b'],
#  'what rights are protected by the ban on animals': ['test-environment-assgbatj-pro01b'],
#  'what should be a ban on animal testing': ['test-environment-assgbatj-pro04b'],
#  'what then is the interest of the animal': ['test-environment-assgbatj-pro02b'],
#  'what type of animals are omnivores': ['test-environment-aeghhgwpe-con01b'],
#  'what type of foods do we eat': ['test-environment-aeghhgwpe-con01a'],
#  'when a research animal is used': ['test-environment-assgbatj-con05a'],
#  'when did the defining order of nature appear': ['test-environment-aeghhgwpe-con03a'],
#  'when to ban animal testing': ['test-environment-assgbatj-pro01b'],
#  'which research area should i study': ['test-environment-assgbatj-con05a'],
#  'why are animals so important': ['test-environment-assgbatj-pro01a'],
#  'why are farm animals cruel': ['test-environment-aeghhgwpe-pro01a'],
#  "why can't we ban animal testing": ['test-environment-assgbatj-pro05a'],
#  'why do humans eat meat': ['test-environment-aeghhgwpe-con03b',
#   'test-environment-aeghhgwpe-con01a'],
#  'why do humans have the right to eat': ['test-environment-aeghhgwpe-pro01b'],
#  'why do people rely on animals science': ['test-environment-assgbatj-con01a'],
#  'why do people test animals': ['test-environment-assgbatj-pro04b'],
#  'why do we ban animal testing': ['test-environment-assgbatj-pro03b'],
#  'why do we believe animal testing is bad': ['test-environment-assgbatj-pro01a'],
#  'why does an animal deserve to be harmed': ['test-environment-assgbatj-pro01a'],
#  'why does animals undergo animal testing?': ['test-environment-assgbatj-con03a'],
#  'why is animal testing necessary': ['test-environment-assgbatj-con04a'],
#  'why is animal testing needed': ['test-environment-assgbatj-con03a'],
#  'why is it bad to do animal testing': ['test-environment-assgbatj-con01b'],
#  'why is it bad to use animal testing': ['test-environment-assgbatj-con03a'],
#  'why is it wrong to eat animal meat?': ['test-environment-aeghhgwpe-pro01b'],
#  'why is it wrong to feed animals in battery farms': ['test-environment-aeghhgwpe-con03b'],
#  'why should animal testing be banned': ['test-environment-assgbatj-pro03b'],
#  'why should we ban animal research': ['test-environment-assgbatj-con04a'],
#  'why was animal testing banned in science': ['test-environment-assgbatj-pro03a'],
#  "will people die if we don't do animal testing": ['test-environment-assgbatj-con02a']}

# %% [markdown]
# ---

# %% [markdown]
# # MAP y AP

# %%
evaluacion_map_jaccard = calcular_map(qrels_dict, search_function=search_jaccard, corpus_preprocessing=corpus_clean_tokenized, corpus=corpus)

print(f"MAP de todo el sistema (promedio de 4 APs): {evaluacion_map_jaccard['MAP']}\n")
print("APs individuales:")
for query, ap_score in evaluacion_map_jaccard['APs_individuales'].items():
    print(f"  '{query}': AP = {ap_score:.4f}")
# Out:
# MAP de todo el sistema (promedio de 4 APs): 0.28449131856565063
#
# APs individuales:
#   'adn natural selection definition in the world': AP = 0.0500
#   'animal tests': AP = 0.0588
#   'are humans animals': AP = 0.1000
#   'are humans omnivores': AP = 0.1667
#   'are meats bad for you': AP = 0.0036
#   'are zoonotic diseases transmitted by animal products': AP = 0.2000
#   'benefits of vegetarian diet': AP = 0.0185
#   'can a scientist test animals': AP = 0.5000
#   'can the government ban animal testing': AP = 0.0051
#   'can the us ban animal testing?': AP = 1.0000
#   'can vegetarians eat a lot of iron': AP = 0.2000
#   'can vegetarians eat cereal': AP = 0.2500
#   'can vegetarians have iron': AP = 0.2500
#   'can we ban animal testing': AP = 0.0167
#   'can you use animal testing?': AP = 0.0500
#   'charles darwin on the origin of species by means of natural selection': AP = 1.0000
#   'could we ban animal testing': AP = 0.5000
#   'deforestation impacts animals environment': AP = 0.0022
#   'do animals need to be slaughtered to have life': AP = 0.0040
#   'does animal testing are necessary': AP = 0.2500
#   'does being a vegetarian cause you to feel depressed and tired': AP = 1.0000
#   'does it have to be cruel to feed animals': AP = 0.0074
#   'does science ban animal testing': AP = 0.0714
#   'does the ban on testing animals come about': AP = 0.0109
#   'how can a healthy diet combat food poisoning': AP = 0.0667
#   'how can we stop animal testing': AP = 0.1429
#   'how cruel are animal slaughter': AP = 0.0119
#   'how does meat affect the environment': AP = 0.0029
#   'how does the food chain prevent food poisoning': AP = 0.0213
#   'how is meat bad for your body': AP = 0.0020
#   'how many drugs are tested in the uk every year': AP = 1.0000
#   'how many people die from animal testing': AP = 1.0000
#   'how much protein is in raw meat': AP = 0.0556
#   'how to ban animal testing': AP = 0.3333
#   'how to judge battery farms morally': AP = 1.0000
#   'is animal research dangerous': AP = 1.0000
#   'is it bad to use animal testing': AP = 0.3333
#   'is it better to be a vegan or vegetarian?': AP = 0.0028
#   'is it good to be vegetarian': AP = 0.0011
#   'is it natural for humans to eat meat': AP = 0.0556
#   'is it necessary to ban animal testing': AP = 0.0127
#   'is meat environmentally harmful': AP = 0.0030
#   'is testing animals ok': AP = 1.0000
#   'should a drug be used in research on humans': AP = 0.1667
#   'should animal research be banned': AP = 0.0625
#   'should i ban testing animals': AP = 0.2000
#   'should research cause severe damage': AP = 0.5000
#   'should we ban animal testing': AP = 0.0476
#   'should you ban testing animals': AP = 0.1667
#   'what are common food poisonings in meat': AP = 0.5000
#   'what are the symptoms of being a vegan': AP = 1.0000
#   'what do you eat to be vegetarian': AP = 0.0556
#   'what does animal testing do to animals': AP = 0.0179
#   'what does animal testing mean': AP = 0.0345
#   'what does the interest of the animal mean': AP = 0.5000
#   'what evolved the human body as an omnivore': AP = 1.0000
#   'what foods can cause food poisoning': AP = 0.3333
#   'what foods have e coli': AP = 0.0833
#   'what is a ban for animals': AP = 0.0286
#   'what is the ban on animal testing': AP = 0.0167
#   'what is the difference between animal testing and health care': AP = 0.2500
#   'what is the difference between harm for the sake of harming an animal and harm in order to save lives?': AP = 0.5000
#   'what is the difference between lifesaving drugs and animal testing': AP = 0.5000
#   'what is the healthy diet of the vegetarian': AP = 0.0417
#   'what is the interest of the animal?': AP = 1.0000
#   'what is the most important driver for deforestation': AP = 0.0013
#   'what is the right of a human to not be harmed based on': AP = 1.0000
#   'what is vegetarian symptoms': AP = 1.0000
#   'what kind of drugs can you give a human': AP = 1.0000
#   'what rights are protected by the ban on animals': AP = 0.0476
#   'what should be a ban on animal testing': AP = 0.0357
#   'what then is the interest of the animal': AP = 1.0000
#   'what type of animals are omnivores': AP = 0.0204
#   'what type of foods do we eat': AP = 0.0040
#   'when a research animal is used': AP = 0.2000
#   'when did the defining order of nature appear': AP = 0.5000
#   'when to ban animal testing': AP = 0.1111
#   'which research area should i study': AP = 0.0154
#   'why are animals so important': AP = 0.0031
#   'why are farm animals cruel': AP = 0.0115
#   'why can't we ban animal testing': AP = 0.0714
#   'why do humans eat meat': AP = 0.1027
#   'why do humans have the right to eat': AP = 0.0116
#   'why do people rely on animals science': AP = 0.0089
#   'why do people test animals': AP = 0.0286
#   'why do we ban animal testing': AP = 1.0000
#   'why do we believe animal testing is bad': AP = 0.0357
#   'why does an animal deserve to be harmed': AP = 0.0182
#   'why does animals undergo animal testing?': AP = 0.0435
#   'why is animal testing necessary': AP = 0.0714
#   'why is animal testing needed': AP = 0.1667
#   'why is it bad to do animal testing': AP = 0.0526
#   'why is it bad to use animal testing': AP = 0.0345
#   'why is it wrong to eat animal meat?': AP = 0.1000
#   'why is it wrong to feed animals in battery farms': AP = 0.5000
#   'why should animal testing be banned': AP = 1.0000
#   'why should we ban animal research': AP = 0.1667
#   'why was animal testing banned in science': AP = 0.0370
#   'will people die if we don't do animal testing': AP = 1.0000

# %%
evaluacion_map_tfidf = calcular_map(qrels_dict, search_function=search_tdifd, vectorizer=vectorizer, tfidf_matrix=matriz_tfidf, corpus=corpus)

print(f"MAP de todo el sistema (promedio de 4 APs): {evaluacion_map_tfidf['MAP']}\n")
print("APs individuales:")
for query, ap_score in evaluacion_map_tfidf['APs_individuales'].items():
    print(f"  '{query}': AP = {ap_score:.4f}")
# Out:
# MAP de todo el sistema (promedio de 4 APs): 0.34271185788501984
#
# APs individuales:
#   'adn natural selection definition in the world': AP = 0.2500
#   'animal tests': AP = 0.0345
#   'are humans animals': AP = 0.0625
#   'are humans omnivores': AP = 1.0000
#   'are meats bad for you': AP = 0.1250
#   'are zoonotic diseases transmitted by animal products': AP = 1.0000
#   'benefits of vegetarian diet': AP = 0.3333
#   'can a scientist test animals': AP = 0.0145
#   'can the government ban animal testing': AP = 0.0714
#   'can the us ban animal testing?': AP = 0.1667
#   'can vegetarians eat a lot of iron': AP = 1.0000
#   'can vegetarians eat cereal': AP = 1.0000
#   'can vegetarians have iron': AP = 1.0000
#   'can we ban animal testing': AP = 0.0095
#   'can you use animal testing?': AP = 0.1250
#   'charles darwin on the origin of species by means of natural selection': AP = 1.0000
#   'could we ban animal testing': AP = 0.5000
#   'deforestation impacts animals environment': AP = 0.0149
#   'do animals need to be slaughtered to have life': AP = 0.0625
#   'does animal testing are necessary': AP = 0.1000
#   'does being a vegetarian cause you to feel depressed and tired': AP = 0.5000
#   'does it have to be cruel to feed animals': AP = 0.0333
#   'does science ban animal testing': AP = 0.1250
#   'does the ban on testing animals come about': AP = 0.0093
#   'how can a healthy diet combat food poisoning': AP = 0.3333
#   'how can we stop animal testing': AP = 0.0526
#   'how cruel are animal slaughter': AP = 0.0588
#   'how does meat affect the environment': AP = 0.2500
#   'how does the food chain prevent food poisoning': AP = 0.2500
#   'how is meat bad for your body': AP = 0.1250
#   'how many drugs are tested in the uk every year': AP = 1.0000
#   'how many people die from animal testing': AP = 0.3333
#   'how much protein is in raw meat': AP = 1.0000
#   'how to ban animal testing': AP = 0.0132
#   'how to judge battery farms morally': AP = 1.0000
#   'is animal research dangerous': AP = 1.0000
#   'is it bad to use animal testing': AP = 0.1667
#   'is it better to be a vegan or vegetarian?': AP = 0.5000
#   'is it good to be vegetarian': AP = 0.5000
#   'is it natural for humans to eat meat': AP = 1.0000
#   'is it necessary to ban animal testing': AP = 0.0213
#   'is meat environmentally harmful': AP = 0.1111
#   'is testing animals ok': AP = 0.0143
#   'should a drug be used in research on humans': AP = 0.0556
#   'should animal research be banned': AP = 0.0333
#   'should i ban testing animals': AP = 0.1667
#   'should research cause severe damage': AP = 0.0769
#   'should we ban animal testing': AP = 0.0357
#   'should you ban testing animals': AP = 0.0233
#   'what are common food poisonings in meat': AP = 1.0000
#   'what are the symptoms of being a vegan': AP = 0.5000
#   'what do you eat to be vegetarian': AP = 0.0714
#   'what does animal testing do to animals': AP = 0.1000
#   'what does animal testing mean': AP = 0.0119
#   'what does the interest of the animal mean': AP = 0.3333
#   'what evolved the human body as an omnivore': AP = 1.0000
#   'what foods can cause food poisoning': AP = 1.0000
#   'what foods have e coli': AP = 0.2500
#   'what is a ban for animals': AP = 0.0714
#   'what is the ban on animal testing': AP = 0.0095
#   'what is the difference between animal testing and health care': AP = 0.0217
#   'what is the difference between harm for the sake of harming an animal and harm in order to save lives?': AP = 1.0000
#   'what is the difference between lifesaving drugs and animal testing': AP = 0.5000
#   'what is the healthy diet of the vegetarian': AP = 0.5000
#   'what is the interest of the animal?': AP = 0.5000
#   'what is the most important driver for deforestation': AP = 0.1111
#   'what is the right of a human to not be harmed based on': AP = 0.0130
#   'what is vegetarian symptoms': AP = 0.3333
#   'what kind of drugs can you give a human': AP = 0.0833
#   'what rights are protected by the ban on animals': AP = 0.2500
#   'what should be a ban on animal testing': AP = 0.0110
#   'what then is the interest of the animal': AP = 0.5000
#   'what type of animals are omnivores': AP = 1.0000
#   'what type of foods do we eat': AP = 0.0345
#   'when a research animal is used': AP = 0.2500
#   'when did the defining order of nature appear': AP = 0.5000
#   'when to ban animal testing': AP = 0.2500
#   'which research area should i study': AP = 0.0156
#   'why are animals so important': AP = 0.0179
#   'why are farm animals cruel': AP = 1.0000
#   'why can't we ban animal testing': AP = 0.1250
#   'why do humans eat meat': AP = 0.5588
#   'why do humans have the right to eat': AP = 0.2000
#   'why do people rely on animals science': AP = 0.0286
#   'why do people test animals': AP = 0.0115
#   'why do we ban animal testing': AP = 1.0000
#   'why do we believe animal testing is bad': AP = 0.0303
#   'why does an animal deserve to be harmed': AP = 0.0294
#   'why does animals undergo animal testing?': AP = 0.0625
#   'why is animal testing necessary': AP = 0.0909
#   'why is animal testing needed': AP = 0.2000
#   'why is it bad to do animal testing': AP = 0.0370
#   'why is it bad to use animal testing': AP = 0.1429
#   'why is it wrong to eat animal meat?': AP = 1.0000
#   'why is it wrong to feed animals in battery farms': AP = 1.0000
#   'why should animal testing be banned': AP = 1.0000
#   'why should we ban animal research': AP = 0.1250
#   'why was animal testing banned in science': AP = 0.0556
#   'will people die if we don't do animal testing': AP = 0.3333

# %%
evaluacion_map_bm25 = calcular_map(qrels_dict, search_function=search_bm25, bm25_model=bm25_model, corpus=corpus)

print(f"MAP de todo el sistema (promedio de 4 APs): {evaluacion_map_bm25['MAP']}\n")
print("APs individuales:")
for query, ap_score in evaluacion_map_bm25['APs_individuales'].items():
    print(f"  '{query}': AP = {ap_score:.4f}")
# Out:
# MAP de todo el sistema (promedio de 4 APs): 0.45255116533020884
#
# APs individuales:
#   'adn natural selection definition in the world': AP = 0.3333
#   'animal tests': AP = 0.0769
#   'are humans animals': AP = 0.0769
#   'are humans omnivores': AP = 1.0000
#   'are meats bad for you': AP = 0.1667
#   'are zoonotic diseases transmitted by animal products': AP = 1.0000
#   'benefits of vegetarian diet': AP = 0.3333
#   'can a scientist test animals': AP = 0.0357
#   'can the government ban animal testing': AP = 0.0189
#   'can the us ban animal testing?': AP = 0.3333
#   'can vegetarians eat a lot of iron': AP = 1.0000
#   'can vegetarians eat cereal': AP = 1.0000
#   'can vegetarians have iron': AP = 1.0000
#   'can we ban animal testing': AP = 0.0087
#   'can you use animal testing?': AP = 0.0588
#   'charles darwin on the origin of species by means of natural selection': AP = 1.0000
#   'could we ban animal testing': AP = 0.5000
#   'deforestation impacts animals environment': AP = 0.2000
#   'do animals need to be slaughtered to have life': AP = 0.1667
#   'does animal testing are necessary': AP = 0.5000
#   'does being a vegetarian cause you to feel depressed and tired': AP = 1.0000
#   'does it have to be cruel to feed animals': AP = 0.0303
#   'does science ban animal testing': AP = 0.0769
#   'does the ban on testing animals come about': AP = 0.0072
#   'how can a healthy diet combat food poisoning': AP = 1.0000
#   'how can we stop animal testing': AP = 0.2000
#   'how cruel are animal slaughter': AP = 0.1111
#   'how does meat affect the environment': AP = 1.0000
#   'how does the food chain prevent food poisoning': AP = 0.5000
#   'how is meat bad for your body': AP = 0.1667
#   'how many drugs are tested in the uk every year': AP = 1.0000
#   'how many people die from animal testing': AP = 1.0000
#   'how much protein is in raw meat': AP = 1.0000
#   'how to ban animal testing': AP = 0.0345
#   'how to judge battery farms morally': AP = 1.0000
#   'is animal research dangerous': AP = 1.0000
#   'is it bad to use animal testing': AP = 1.0000
#   'is it better to be a vegan or vegetarian?': AP = 0.3333
#   'is it good to be vegetarian': AP = 0.3333
#   'is it natural for humans to eat meat': AP = 1.0000
#   'is it necessary to ban animal testing': AP = 0.0108
#   'is meat environmentally harmful': AP = 0.5000
#   'is testing animals ok': AP = 0.0385
#   'should a drug be used in research on humans': AP = 0.1429
#   'should animal research be banned': AP = 0.0526
#   'should i ban testing animals': AP = 0.1250
#   'should research cause severe damage': AP = 1.0000
#   'should we ban animal testing': AP = 0.0435
#   'should you ban testing animals': AP = 0.0500
#   'what are common food poisonings in meat': AP = 1.0000
#   'what are the symptoms of being a vegan': AP = 1.0000
#   'what do you eat to be vegetarian': AP = 0.1429
#   'what does animal testing do to animals': AP = 0.0370
#   'what does animal testing mean': AP = 0.0093
#   'what does the interest of the animal mean': AP = 0.5000
#   'what evolved the human body as an omnivore': AP = 1.0000
#   'what foods can cause food poisoning': AP = 1.0000
#   'what foods have e coli': AP = 1.0000
#   'what is a ban for animals': AP = 0.0385
#   'what is the ban on animal testing': AP = 0.0087
#   'what is the difference between animal testing and health care': AP = 0.0213
#   'what is the difference between harm for the sake of harming an animal and harm in order to save lives?': AP = 1.0000
#   'what is the difference between lifesaving drugs and animal testing': AP = 1.0000
#   'what is the healthy diet of the vegetarian': AP = 0.5000
#   'what is the interest of the animal?': AP = 1.0000
#   'what is the most important driver for deforestation': AP = 0.2500
#   'what is the right of a human to not be harmed based on': AP = 0.5000
#   'what is vegetarian symptoms': AP = 1.0000
#   'what kind of drugs can you give a human': AP = 0.5000
#   'what rights are protected by the ban on animals': AP = 0.0323
#   'what should be a ban on animal testing': AP = 0.0085
#   'what then is the interest of the animal': AP = 1.0000
#   'what type of animals are omnivores': AP = 0.5000
#   'what type of foods do we eat': AP = 0.0238
#   'when a research animal is used': AP = 0.5000
#   'when did the defining order of nature appear': AP = 1.0000
#   'when to ban animal testing': AP = 0.1667
#   'which research area should i study': AP = 0.0115
#   'why are animals so important': AP = 0.0154
#   'why are farm animals cruel': AP = 0.5000
#   'why can't we ban animal testing': AP = 0.0833
#   'why do humans eat meat': AP = 0.5769
#   'why do humans have the right to eat': AP = 1.0000
#   'why do people rely on animals science': AP = 0.0137
#   'why do people test animals': AP = 0.0093
#   'why do we ban animal testing': AP = 0.5000
#   'why do we believe animal testing is bad': AP = 0.1250
#   'why does an animal deserve to be harmed': AP = 0.0769
#   'why does animals undergo animal testing?': AP = 0.2000
#   'why is animal testing necessary': AP = 0.0625
#   'why is animal testing needed': AP = 0.3333
#   'why is it bad to do animal testing': AP = 0.0455
#   'why is it bad to use animal testing': AP = 0.2500
#   'why is it wrong to eat animal meat?': AP = 1.0000
#   'why is it wrong to feed animals in battery farms': AP = 1.0000
#   'why should animal testing be banned': AP = 0.5000
#   'why should we ban animal research': AP = 0.1111
#   'why was animal testing banned in science': AP = 0.0833
#   'will people die if we don't do animal testing': AP = 1.0000

# %% [markdown]
# ---

# %% [markdown]
# #  Precision y Recall

# %%
qrels_dict
# Out:
# {'adn natural selection definition in the world': ['test-environment-aeghhgwpe-con03a'],
#  'animal tests': ['test-environment-assgbatj-con03b'],
#  'are humans animals': ['test-environment-assgbatj-con01a'],
#  'are humans omnivores': ['test-environment-aeghhgwpe-con01b'],
#  'are meats bad for you': ['test-environment-aeghhgwpe-pro03a'],
#  'are zoonotic diseases transmitted by animal products': ['test-environment-aeghhgwpe-pro04b'],
#  'benefits of vegetarian diet': ['test-environment-aeghhgwpe-pro03a'],
#  'can a scientist test animals': ['test-environment-assgbatj-con05b'],
#  'can the government ban animal testing': ['test-environment-assgbatj-con05a'],
#  'can the us ban animal testing?': ['test-environment-assgbatj-con04b'],
#  'can vegetarians eat a lot of iron': ['test-environment-aeghhgwpe-con02b'],
#  'can vegetarians eat cereal': ['test-environment-aeghhgwpe-con02b'],
#  'can vegetarians have iron': ['test-environment-aeghhgwpe-con02b'],
#  'can we ban animal testing': ['test-environment-assgbatj-pro04a'],
#  'can you use animal testing?': ['test-environment-assgbatj-pro05a'],
#  'charles darwin on the origin of species by means of natural selection': ['test-environment-aeghhgwpe-con03a'],
#  'could we ban animal testing': ['test-environment-assgbatj-pro03b'],
#  'deforestation impacts animals environment': ['test-environment-aeghhgwpe-pro02a'],
#  'do animals need to be slaughtered to have life': ['test-environment-aeghhgwpe-pro01a'],
#  'does animal testing are necessary': ['test-environment-assgbatj-pro03a'],
#  'does being a vegetarian cause you to feel depressed and tired': ['test-environment-aeghhgwpe-con02a'],
#  'does it have to be cruel to feed animals': ['test-environment-aeghhgwpe-pro01b'],
#  'does science ban animal testing': ['test-environment-assgbatj-pro05a'],
#  'does the ban on testing animals come about': ['test-environment-assgbatj-pro04a'],
#  'how can a healthy diet combat food poisoning': ['test-environment-aeghhgwpe-pro04b'],
#  'how can we stop animal testing': ['test-environment-assgbatj-con01b'],
#  'how cruel are animal slaughter': ['test-environment-aeghhgwpe-pro01a'],
#  'how does meat affect the environment': ['test-environment-aeghhgwpe-pro02a'],
#  'how does the food chain prevent food poisoning': ['test-environment-aeghhgwpe-pro04b'],
#  'how is meat bad for your body': ['test-environment-aeghhgwpe-pro03a'],
#  'how many drugs are tested in the uk every year': ['test-environment-assgbatj-con02a'],
#  'how many people die from animal testing': ['test-environment-assgbatj-con02a'],
#  'how much protein is in raw meat': ['test-environment-aeghhgwpe-pro03b'],
#  'how to ban animal testing': ['test-environment-assgbatj-con05b'],
#  'how to judge battery farms morally': ['test-environment-aeghhgwpe-con03b'],
#  'is animal research dangerous': ['test-environment-assgbatj-pro02a'],
#  'is it bad to use animal testing': ['test-environment-assgbatj-con04b'],
#  'is it better to be a vegan or vegetarian?': ['test-environment-aeghhgwpe-pro02b'],
#  'is it good to be vegetarian': ['test-environment-aeghhgwpe-pro02b'],
#  'is it natural for humans to eat meat': ['test-environment-aeghhgwpe-con01a'],
#  'is it necessary to ban animal testing': ['test-environment-assgbatj-con01a'],
#  'is meat environmentally harmful': ['test-environment-aeghhgwpe-pro02b'],
#  'is testing animals ok': ['test-environment-assgbatj-con05b'],
#  'should a drug be used in research on humans': ['test-environment-assgbatj-con03b'],
#  'should animal research be banned': ['test-environment-assgbatj-pro03a'],
#  'should i ban testing animals': ['test-environment-assgbatj-con04b'],
#  'should research cause severe damage': ['test-environment-assgbatj-pro02a'],
#  'should we ban animal testing': ['test-environment-assgbatj-con01b'],
#  'should you ban testing animals': ['test-environment-assgbatj-con02b'],
#  'what are common food poisonings in meat': ['test-environment-aeghhgwpe-pro04a'],
#  'what are the symptoms of being a vegan': ['test-environment-aeghhgwpe-con02a'],
#  'what do you eat to be vegetarian': ['test-environment-aeghhgwpe-pro03b'],
#  'what does animal testing do to animals': ['test-environment-assgbatj-pro02a'],
#  'what does animal testing mean': ['test-environment-assgbatj-pro04b'],
#  'what does the interest of the animal mean': ['test-environment-assgbatj-pro02b'],
#  'what evolved the human body as an omnivore': ['test-environment-aeghhgwpe-con01b'],
#  'what foods can cause food poisoning': ['test-environment-aeghhgwpe-pro04a'],
#  'what foods have e coli': ['test-environment-aeghhgwpe-pro04a'],
#  'what is a ban for animals': ['test-environment-assgbatj-con04a'],
#  'what is the ban on animal testing': ['test-environment-assgbatj-pro04a'],
#  'what is the difference between animal testing and health care': ['test-environment-assgbatj-pro05b'],
#  'what is the difference between harm for the sake of harming an animal and harm in order to save lives?': ['test-environment-assgbatj-pro05b'],
#  'what is the difference between lifesaving drugs and animal testing': ['test-environment-assgbatj-pro05b'],
#  'what is the healthy diet of the vegetarian': ['test-environment-aeghhgwpe-pro03b'],
#  'what is the interest of the animal?': ['test-environment-assgbatj-pro02b'],
#  'what is the most important driver for deforestation': ['test-environment-aeghhgwpe-pro02a'],
#  'what is the right of a human to not be harmed based on': ['test-environment-assgbatj-pro01b'],
#  'what is vegetarian symptoms': ['test-environment-aeghhgwpe-con02a'],
#  'what kind of drugs can you give a human': ['test-environment-assgbatj-con03b'],
#  'what rights are protected by the ban on animals': ['test-environment-assgbatj-pro01b'],
#  'what should be a ban on animal testing': ['test-environment-assgbatj-pro04b'],
#  'what then is the interest of the animal': ['test-environment-assgbatj-pro02b'],
#  'what type of animals are omnivores': ['test-environment-aeghhgwpe-con01b'],
#  'what type of foods do we eat': ['test-environment-aeghhgwpe-con01a'],
#  'when a research animal is used': ['test-environment-assgbatj-con05a'],
#  'when did the defining order of nature appear': ['test-environment-aeghhgwpe-con03a'],
#  'when to ban animal testing': ['test-environment-assgbatj-pro01b'],
#  'which research area should i study': ['test-environment-assgbatj-con05a'],
#  'why are animals so important': ['test-environment-assgbatj-pro01a'],
#  'why are farm animals cruel': ['test-environment-aeghhgwpe-pro01a'],
#  "why can't we ban animal testing": ['test-environment-assgbatj-pro05a'],
#  'why do humans eat meat': ['test-environment-aeghhgwpe-con03b',
#   'test-environment-aeghhgwpe-con01a'],
#  'why do humans have the right to eat': ['test-environment-aeghhgwpe-pro01b'],
#  'why do people rely on animals science': ['test-environment-assgbatj-con01a'],
#  'why do people test animals': ['test-environment-assgbatj-pro04b'],
#  'why do we ban animal testing': ['test-environment-assgbatj-pro03b'],
#  'why do we believe animal testing is bad': ['test-environment-assgbatj-pro01a'],
#  'why does an animal deserve to be harmed': ['test-environment-assgbatj-pro01a'],
#  'why does animals undergo animal testing?': ['test-environment-assgbatj-con03a'],
#  'why is animal testing necessary': ['test-environment-assgbatj-con04a'],
#  'why is animal testing needed': ['test-environment-assgbatj-con03a'],
#  'why is it bad to do animal testing': ['test-environment-assgbatj-con01b'],
#  'why is it bad to use animal testing': ['test-environment-assgbatj-con03a'],
#  'why is it wrong to eat animal meat?': ['test-environment-aeghhgwpe-pro01b'],
#  'why is it wrong to feed animals in battery farms': ['test-environment-aeghhgwpe-con03b'],
#  'why should animal testing be banned': ['test-environment-assgbatj-pro03b'],
#  'why should we ban animal research': ['test-environment-assgbatj-con04a'],
#  'why was animal testing banned in science': ['test-environment-assgbatj-pro03a'],
#  "will people die if we don't do animal testing": ['test-environment-assgbatj-con02a']}

# %%
query_general = 'benefits of vegetarian diet'
ids_relevantes_ejemplo = set(qrels_dict[query_general])

# %%
result_jacard = search_jaccard(query_general, corpus_clean_tokenized, corpus)
result_tfidf = search_tdifd(query_general, vectorizer, matriz_tfidf, corpus)
result_bm25 = search_bm25(query_general, bm25_model, corpus)

# %%
metricas = calcular_precision_recall(result_jacard, ids_relevantes_ejemplo, k=10)
print(f"Precisión@: {metricas['precision@k']:.4f}, Recall@: {metricas['recall@k']:.4f}")
# Out:
# Precisión@: 0.0000, Recall@: 0.0000

# %%
metricas = calcular_precision_recall(result_tfidf, ids_relevantes_ejemplo, k=10)
print(f"Precisión@: {metricas['precision@k']:.4f}, Recall@: {metricas['recall@k']:.4f}")
# Out:
# Precisión@: 0.1000, Recall@: 1.0000

# %%
metricas = calcular_precision_recall(result_bm25, ids_relevantes_ejemplo, k=10)
print(f"Precisión@: {metricas['precision@k']:.4f}, Recall@: {metricas['recall@k']:.4f}")
# Out:
# Precisión@: 0.1000, Recall@: 1.0000
