# %%
from mceclib.preprocessing import *
from mceclib.jaccard import *
from mceclib.tfidf import *
from mceclib.bm25 import *

# %%
import gzip
import json
import pandas as pd

path = './data/'

# Leer archivo comprimido .jsonl.gz
with gzip.open(path + 'corpus.jsonl.gz', 'rt', encoding='utf-8') as file:
    lines = file.readlines()

# Procesar el archivo línea por línea y convertirlo en un DataFrame
data = [json.loads(line) for line in lines]

# Convertir en DataFrame
df = pd.DataFrame(data)
df[['_id','text']]
# Out:
#                                       _id  \
# 0       test-environment-aeghhgwpe-pro02b
# 1       test-environment-aeghhgwpe-pro02a
# 2       test-environment-aeghhgwpe-pro03b
# 3       test-environment-aeghhgwpe-pro01a
# 4       test-environment-aeghhgwpe-pro01b
# ...                                   ...
# 8669  validation-society-fyhwscdcj-con01b
# 8670  validation-society-fyhwscdcj-con02a
# 8671  validation-society-fyhwscdcj-con03a
# 8672  validation-society-fyhwscdcj-con01a
# 8673  validation-society-fyhwscdcj-con02b
#
#                                                    text
# 0     You don’t have to be vegetarian to be green. M...
# 1     Being vegetarian helps the environment  Becomi...
# 2     The key to good health is a balanced diet, not...
# 3     It is immoral to kill animals  As evolved huma...
# 4     There is a great moral difference between huma...
# ...                                                 ...
# 8669  Stories about ridiculous administration costs ...
# 8670  We need to address the causes of poverty rathe...
# 8671  Sponsorship is often more about the intentions...
# 8672  Sponsorship is an inefficient way of giving to...
# 8673  Many of the organisations that run child spons...
#
# [8674 rows x 2 columns]

# %%
corpus_original = df[['_id','text']]

# %%
type(corpus_original)
# Out:
# pandas.core.frame.DataFrame

# %%
corpus_clean = corpus_original["text"].apply(preprocessing2text)
corpus_clean_df = pd.DataFrame({
    '_id': corpus_original['_id'],
    'textprocesado': corpus_clean
})

# %%
corpus_clean_df
# Out:
#                                       _id  \
# 0       test-environment-aeghhgwpe-pro02b
# 1       test-environment-aeghhgwpe-pro02a
# 2       test-environment-aeghhgwpe-pro03b
# 3       test-environment-aeghhgwpe-pro01a
# 4       test-environment-aeghhgwpe-pro01b
# ...                                   ...
# 8669  validation-society-fyhwscdcj-con01b
# 8670  validation-society-fyhwscdcj-con02a
# 8671  validation-society-fyhwscdcj-con03a
# 8672  validation-society-fyhwscdcj-con01a
# 8673  validation-society-fyhwscdcj-con02b
#
#                                           textprocesado
# 0     vegetarian green mani special environ creat li...
# 1     vegetarian help environ becom vegetarian envir...
# 2     key good health balanc diet meat fishfre diet ...
# 3     immor kill anim evolv human be moral duti infl...
# 4     great moral differ human anim unlik anim human...
# ...                                                 ...
# 8669  stori ridicul administr cost rare often untru ...
# 8670  need address caus poverti rather treat symptom...
# 8671  sponsorship often intent donor rather need poo...
# 8672  sponsorship ineffici way give chariti sponsor ...
# 8673  mani organis run child sponsorship scheme dedi...
#
# [8674 rows x 2 columns]

# %%
corpus_clean_tokenized = corpus_clean.apply(tokenize_text)
corpus_clean_tokenized_df = pd.DataFrame({
    '_id': corpus_original['_id'],
    'tokens': corpus_clean_tokenized
})
corpus_clean_tokenized_df
# Out:
#                                       _id  \
# 0       test-environment-aeghhgwpe-pro02b
# 1       test-environment-aeghhgwpe-pro02a
# 2       test-environment-aeghhgwpe-pro03b
# 3       test-environment-aeghhgwpe-pro01a
# 4       test-environment-aeghhgwpe-pro01b
# ...                                   ...
# 8669  validation-society-fyhwscdcj-con01b
# 8670  validation-society-fyhwscdcj-con02a
# 8671  validation-society-fyhwscdcj-con03a
# 8672  validation-society-fyhwscdcj-con01a
# 8673  validation-society-fyhwscdcj-con02b
#
#                                                  tokens
# 0     [vegetarian, green, mani, special, environ, cr...
# 1     [vegetarian, help, environ, becom, vegetarian,...
# 2     [key, good, health, balanc, diet, meat, fishfr...
# 3     [immor, kill, anim, evolv, human, be, moral, d...
# 4     [great, moral, differ, human, anim, unlik, ani...
# ...                                                 ...
# 8669  [stori, ridicul, administr, cost, rare, often,...
# 8670  [need, address, caus, poverti, rather, treat, ...
# 8671  [sponsorship, often, intent, donor, rather, ne...
# 8672  [sponsorship, ineffici, way, give, chariti, sp...
# 8673  [mani, organis, run, child, sponsorship, schem...
#
# [8674 rows x 2 columns]

# %% [markdown]
# # Jacard
# * corpus_clean_tokenized
# * corpus_original

# %%
query_jacard = "daughter spiderman"

# %%
result_jacard = search_jaccard(query_jacard, corpus_clean_tokenized_df, corpus_original)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 result_jacard = search_jaccard(query_jacard, corpus_clean_tokenized_df, corpus_original)
#
# File ~\PycharmProjects\ProyectoIB\mceclib\jaccard.py:40, in search_jaccard(query_text, corpus_preprocessing, corpus, op)
#      38 query_tokens = preprocessing2tokens(query_text, op=op)
#      39 jaccard_scores = []
# ---> 40 for id, doc_tokens in corpus_preprocessing:
#      41     score = jaccard_similarity(query_tokens, doc_tokens)
#      42     jaccard_scores.append(score)
#
# ValueError: too many values to unpack (expected 2)

# %%
result_jacard
# Out:
#       doc_index                                            reviews    scores
# 0          5379  It is for the individuals to decide whether th...  0.020000
# 1           395  The painting should remain hanging as a remind...  0.019231
# 2          5374  This argument veils the likely result of the p...  0.014925
# 3          7275  No clear dividing line between public and priv...  0.014925
# 4          8636  Abortion  It is estimated that around 10 milli...  0.012987
# ...         ...                                                ...       ...
# 8669       8637  Whilst the Indian government may have policies...  0.000000
# 8670       8655  This policy breaks down important inter-govern...  0.000000
# 8671       8639  Commodifying women.  Surely providing a financ...  0.000000
# 8672       8640  Autonomy (Please note that this argument canno...  0.000000
# 8673       7589  Minorities deserve linguistic rights  Everyone...  0.000000
#
# [8674 rows x 3 columns]

# %% [markdown]
# # TF-IDF
# * corpus_clean
# * corpus_original

# %%
query_tfidf = "daughter spiderman"

# %%
matriz_tfidf, vectorizer = build_tfidf(corpus_clean)

# %%
result_tfidf = search_tdifd(query_tfidf, vectorizer, matriz_tfidf, corpus_original)

# %%
result_tfidf
# Out:
#       doc_index                                            reviews    scores
# 0          7627  The one child policy skews gender demographics...  0.208172
# 1          8536  Fixating on personal lives results in infringi...  0.176949
# 2          7275  No clear dividing line between public and priv...  0.141395
# 3           395  The painting should remain hanging as a remind...  0.107502
# 4          5379  It is for the individuals to decide whether th...  0.102044
# ...         ...                                                ...       ...
# 8669       8637  Whilst the Indian government may have policies...  0.000000
# 8670       8655  This policy breaks down important inter-govern...  0.000000
# 8671       8639  Commodifying women.  Surely providing a financ...  0.000000
# 8672       8640  Autonomy (Please note that this argument canno...  0.000000
# 8673       7589  Minorities deserve linguistic rights  Everyone...  0.000000
#
# [8674 rows x 3 columns]

# %%
simple_result_tfidf = simple_search_tdifd(query_tfidf,vectorizer, matriz_tfidf, corpus_original)
simple_result_tfidf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 simple_result_tfidf = simple_search_tdifd(query_tfidf,vectorizer, matriz_tfidf, corpus_original)
#       2 simple_result_tfidf
#
# NameError: name 'simple_search_tdifd' is not defined

# %% [markdown]
# # BM25
# * corpus_clean_tokenized
# * corpus_original

# %%
query_bm25 = "daughter spiderman"

# %%
bm25_model = build_bm25_model(corpus_clean_tokenized)

# %%
result_bm25 = search_bm25(query_bm25, bm25_model, corpus_original)

# %%
result_bm25
# Out:
#       doc_index                                            reviews    scores
# 0          7627  The one child policy skews gender demographics...  9.938928
# 1          8536  Fixating on personal lives results in infringi...  9.019144
# 2          7275  No clear dividing line between public and priv...  8.761588
# 3          5379  It is for the individuals to decide whether th...  7.415137
# 4           395  The painting should remain hanging as a remind...  7.369124
# ...         ...                                                ...       ...
# 8669       8637  Whilst the Indian government may have policies...  0.000000
# 8670       8655  This policy breaks down important inter-govern...  0.000000
# 8671       8639  Commodifying women.  Surely providing a financ...  0.000000
# 8672       8640  Autonomy (Please note that this argument canno...  0.000000
# 8673       7589  Minorities deserve linguistic rights  Everyone...  0.000000
#
# [8674 rows x 3 columns]

# %% [markdown]
# # qrels

# %%
path = './data/'

# Leer archivo comprimido .jsonl.gz
with gzip.open(path + 'train.jsonl.gz', 'rt', encoding='utf-8') as file:
    lines = file.readlines()

# Procesar el archivo línea por línea y convertirlo en un DataFrame
queriesdt = [json.loads(line) for line in lines]

# Convertir en DataFrame
queries = pd.DataFrame(queriesdt)
queries[['_id','text', 'query']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 path = './data/'
#       3 # Leer archivo comprimido .jsonl.gz
# ----> 4 with gzip.open(path + 'train.jsonl.gz', 'rt', encoding='utf-8') as file:
#       5     lines = file.readlines()
#       7 # Procesar el archivo línea por línea y convertirlo en un DataFrame
#
# NameError: name 'gzip' is not defined

# %%
qrels_dict= queries[['_id','text', 'query']].groupby('query')['_id'].apply(list).to_dict()

# %%
qrels_dict
# Out:
# {"'you are an attorney'": ['test-law-lghbacpsba-pro04a'],
#  '2% of non-voters say it is good to have two parties.': ['training-politics-viwvfpps-con04a'],
#  "Assad's government what does it do": ['training-international-mepdwhwhwi-con04b'],
#  'Jeremy Corbyn what is his political agenda': ['training-politics-yppplhbmlgl-pro03a'],
#  '____ is the right of being freedomd from the government without endangering human life.': ['training-philosophy-iilepphbf-pro01b'],
#  "________ is a type of assimilation that is inherently based on a nation's heritage.": ['training-culture-tphwpac-con02b'],
#  '________.does not exist in the era of invention': ['training-science-cidfiphwa-pro05b'],
#  'a common misunderstanding between the public and the private sector is that the government': ['training-economy-eptppppgh-pro01b'],
#  'a country should not be burdened by a country': ['test-politics-pgsimhwoia-pro01b'],
#  'a gay couple can be compelled by law to testify or provide evidence against one another.': ['training-religion-msgfhwagcm-pro02a'],
#  'a life save many junior moral definition': ['test-philosophy-elkosmj-con02b'],
#  'a natural market monopoly is a consequence of the underlying cost structure of the industry.': ['training-economy-epegppphw-con01b'],
#  'a number of security issues could come to uk from europe': ['training-international-epdtwhblew-con02a'],
#  'a population of around 2,000 people is the main problem for the government of drc': ['training-international-aghbuidrch-con03a'],
#  'a priori definition of rights': ['training-international-glhrilpws-pro02b'],
#  'a progressive tax regime essentially assumes the': ['test-economy-thsptr-con01a'],
#  'a reasonable level of existence does not require a remuneration': ['validation-religion-cfhwksdr-con03b'],
#  'a referendum would be a waste of money': ['training-international-epgvhwhrum-pro02b'],
#  'a right of reply': ['training-free-speech-debate-radhbrr-con01a'],
#  'a right to know': ['test-free-speech-debate-fsaphgiap-pro01b'],
#  'a solution for eastern europe is that': ['training-international-agphwen-con01b'],
#  'a statement that is based on the un charter is that': ['training-international-glilhbmai-con01a'],
#  'a technology that is required to colonize another planet could be developed on the moon': ['training-science-sguhwcm-pro02a'],
#  'a united nations army would be': ['test-international-gpdwhwcusa-pro02a'],
#  'a zero tolerance policing is': ['training-society-gmhbztpgtf-pro03b'],
#  'a.the vs the c.the d.the the d. the client. the d.the e.the d. the desire of the client in sexual activity. what is the relationship between the two parties': ['training-law-lgsghwlp-con03b'],
#  'abolition of intellectual property effects': ['training-science-cidfiphwa-pro01a'],
#  'acta definition': ['training-international-gsciidfi-con03a'],
#  'acta definition of liberties': ['training-international-gsciidfi-con03a'],
#  'adn natural selection definition in the world': ['test-environment-aeghhgwpe-con03a'],
#  'advantage of microfinance scheme': ['test-international-eiahwpamu-con01b'],
#  'advantages of cash transfers': ['validation-international-aghwgcprp-con01a'],
#  'advantages of diversity in the workplace': ['training-economy-bepeechbem-pro03a'],
#  'advantages of dna fingerprinting': ['training-law-cplghwhcdd-con02b'],
#  'advantages of gaining life experience in university': ['training-education-eguhwefpgu-con02a'],
#  'advantages of hyperloop': ['test-economy-beghwbh-con03b'],
#  'advantages of imports': ['validation-economy-beghwarirgg-pro01a'],
#  'advantages of online learning': ['test-education-egtuscpih-pro01a'],
#  'advertising costs in healthcare': ['training-health-bhhghwapc-con03a'],
#  'affect of unemployment': ['test-economy-epiasghbf-pro02a'],
#  'affirmative action law meaning': ['test-education-usuprmhbu-pro03b'],
#  'afghanistan infrastructure deteriorates when': ['training-politics-dtwhbnhsa-pro04b'],
#  'afghanistan is the graveyard of empires metaphor': ['validation-international-atwhwatw-con02b'],
#  'afghanistan military withdrawal': ['validation-international-atwhwatw-con01a'],
#  'afghanistan peacekeeping force examples': ['training-international-aghwaucsa-pro01a'],
#  'afria definition': ['training-international-aghwrpusvpa-con04b'],
#  'africa is dependent on exports': ['training-economy-fegippghp-con03a'],
#  'africa what does it need foreign aid': ['training-international-aghwrpusvpa-pro03b'],
#  "africa's largest armed conflict was the": ['training-international-apdwhbpa-pro03a'],
#  'african aid laws effecting african': ['training-health-ssiahrgmhwc-pro02a'],
#  'african conflict number': ['test-international-apwhbaucmip-con02a'],
#  'african constitution objective': ['training-international-amehwrabre-con04a'],
#  'african countries which have lowered poverty': ['test-international-segiahbarr-pro02a'],
#  'african football economic impact': ['training-international-astshbghacn-con01a'],
#  'african government estimates cyber terrorism cost': ['test-international-siacphbnt-con03a'],
#  'african mdg goals': ['test-international-segiahbarr-con01a'],
#  'african national cup of nations ticket sale': ['training-international-astshbghacn-con02b'],
#  'african nations to support efforts to recover africa': ['training-international-aptwhbfri-con02a'],
#  'african peacekeeping costs': ['training-international-aghwaucsa-con01a'],
#  'african politics can change how men and women do': ['training-politics-oapglvsghw-pro03a'],
#  'african union has no icc': ['training-law-ilphbined-con03b'],
#  'african war peace house': ['test-international-apwhbaucmip-pro04b'],
#  'african women in politics': ['test-economy-egiahbwaka-pro02b'],
#  'age discrimination': ['training-economy-bepeechbem-pro01b'],
#  'age discrimination on adopting': ['training-society-gfhbhsbaa-pro03b'],
#  'age for european parliament member': ['training-international-epvhwav1ep-pro01a'],
#  'age for gymnastics': ['test-culture-mmctyshwbcp-con01b'],
#  'age kids can leave school': ['training-education-egshwrsla1-con03b'],
#  'age limit for performing': ['training-culture-cgpdhwecns-pro03a'],
#  'age limit for voting': ['training-politics-vhwlva1-con04b'],
#  'age of college football players': ['training-sport-tshwipclaf-con02b'],
#  'age of consent causes': ['training-society-gyhbaclsbmmll-con03a'],
#  'age of consent definition': ['training-society-gyhbaclsbmmll-pro03a',
#   'training-society-gyhbaclsbmmll-con01b',
#   'training-society-gyhbaclsbmmll-con01a',
#   'training-society-gyhbaclsbmmll-con02b'],
#  'age of consent definition law': ['training-society-gyhbaclsbmmll-con02b'],
#  'age of consent for children': ['training-society-gyhbaclsbmmll-pro04b'],
#  'age of consent for kids': ['training-society-gyhbaclsbmmll-pro04b'],
#  'age of consent law': ['training-society-gyhbaclsbmmll-pro02a',
#   'training-society-gyhbaclsbmmll-con03b',
#   'training-society-gyhbaclsbmmll-con01a'],
#  'age of consent law definition': ['training-society-gyhbaclsbmmll-con01b',
#   'training-society-gyhbaclsbmmll-con01a'],
#  'age of consent laws': ['training-society-gyhbaclsbmmll-pro03b',
#   'training-society-gyhbaclsbmmll-pro04a',
#   'training-society-gyhbaclsbmmll-con02b'],
#  'age of consent laws definition': ['training-society-gyhbaclsbmmll-pro04a'],
#  'age of protest vs. election': ['training-international-epvhwav1ep-pro05a'],
#  'age of retirement for older persons': ['training-economy-epeshwimra-con01b'],
#  'age of voting in europe': ['training-international-epvhwav1ep-pro01b'],
#  'age of youth in germany': ['training-international-epvhwav1ep-pro03a'],
#  'age to have a child formally': ['training-law-lgpisyhwhcdt-con01b'],
#  'age you can vote in the european parliament': ['training-international-epvhwav1ep-pro01a'],
#  'aid is needed to put children into school': ['training-economy-epiaghwssd-con04a'],
#  'aid to aid': ['training-economy-fegippghp-con01a'],
#  'allowing the market to run unfettered': ['training-philosophy-pppghwblro-pro02b'],
#  'alternative methods of replacing slums': ['training-economy-epiasfhbac-con03a'],
#  'america should stop trying to intern without trial': ['validation-law-lghrilthwdt-con02a'],
#  "america's underground economy": ['training-economy-befhwimsc-pro01b'],
#  'amnesty definition': ['test-law-sdiflhrdffe-con03b'],
#  'amnesty international definition': ['training-society-ihwgaii-pro01a'],
#  'amnesty political definition': ['test-law-sdiflhrdffe-pro03a'],
#  'amnesty to increase illegal immigration': ['training-society-ihwgaii-con03a'],
#  'amnesty what does it mean': ['test-law-sdiflhrdffe-pro03a'],
#  'amoral responsibility definition': ['training-environment-aelmmhbahr-con02b'],
#  'anarchist community definition': ['training-philosophy-pgppghba-con03a'],
#  'anarchist culture definition': ['training-philosophy-pgppghba-con03a'],
#  'animal testing definition': ['test-science-eassgbatj-pro05b'],
#  'animal tests': ['test-environment-assgbatj-con03b'],
#  'anorexics fear of weight gain in hospital': ['training-health-mchdhgwhwff-con02a'],
#  'apathy reasons': ['validation-digital-freedoms-gthwaueai-con03a'],
#  'arctic oil reserves': ['training-environment-cephwcear-con01a'],
#  'are 3d printers illegal': ['training-environment-pscisghwbs3-pro05b'],
#  'are a child rights policy good': ['training-society-gfyhbprcsao-pro02b'],
#  'are a legislators term limited': ['training-philosophy-eppppghwe-con02b'],
#  'are abattoirs considered to be ethical': ['training-environment-ahwbsawhnbsf-pro04b'],
#  'are accusations and accusations the same thing': ['training-free-speech-debate-nshbbhnpsb-pro01a'],
#  'are advertisements harmful': ['test-culture-mthbah-con01a'],
#  'are adverts harmful': ['test-culture-mthbah-pro03a'],
#  'are african states vulnerable to climate change': ['training-environment-cpiahwdwf-pro04a'],
#  'are african women a part of the economy': ['test-economy-egiahbwaka-pro01b'],
#  'are alcohol and tobacco legal': ['test-law-tahglcphsld-pro06b'],
#  'are alcohol cigarettes dangerous': ['training-health-adhgphwfrs-pro02b'],
#  'are alcohol or tobacco illegal': ['training-culture-vgcpiyhwrvv-con03b'],
#  'are all arranged marriages abusive': ['test-religion-msgfhwbamec-pro03b'],
#  'are all head of states the same': ['test-law-ralhrilglv-con01b'],
#  'are all women shortlists an insult': ['validation-politics-pggsghwip-con04b'],
#  'are all women shortlists legal': ['validation-politics-pggsghwip-con03a'],
#  'are alternative medical practitioners more likely to treat a person': ['test-health-dhghhbampt-con03a'],
#  'are alternative medicine good': ['test-health-dhghhbampt-pro03a'],
#  'are alternative meds needed': ['test-health-dhghhbampt-con03a'],
#  'are animal testing harmful': ['test-science-eassgbatj-con02b'],
#  'are animals and learning disabled protected': ['training-environment-aelmmhbahr-pro05a'],
#  'are animals considered human rights': ['training-environment-ahwbsawhnbsf-con01a'],
#  'are animals human or animal': ['training-environment-aelmmhbahr-con03a'],
#  'are animals moral agents': ['training-environment-aelmmhbahr-con02a'],
#  'are animals protected by human rights': ['training-environment-aelmmhbahr-pro05a'],
#  'are antibiotics profitable': ['training-international-gsciidfi-pro02b'],
#  'are antipersonnel mines harmful': ['training-international-gpwhuwsocb-pro02a'],
#  'are artefacts transportable': ['training-education-aetuhwrcp-con04b'],
#  'are artists responsible for their art?': ['training-digital-freedoms-iphwclcp-pro02b'],
#  'are artists restricted': ['test-culture-ahrtsdlgra-pro02a'],
#  'are asbos abused': ['training-law-cplgpsyhwsas-con02a'],
#  'are asean sanctions the same as sanctions?': ['training-politics-dwdfiphwut-con01b'],
#  'are assault weapons illegal in the usa': ['training-law-cphwusbaw-con02b'],
#  'are assault weapons useful': ['training-law-cphwusbaw-pro02a'],
#  'are assisted suicide and euthanasia wrong': ['test-health-dhpelhbass-con03a'],
#  'are authoritarian regimes durable?': ['test-economy-bepighbdb-pro02b'],
#  'are badgers legal': ['training-environment-ahwcb-pro03b'],
#  'are barrier contraception needed to prevent the spread of hiv': ['test-international-ssiarcmhb-pro02b'],
#  'are biometric data needed': ['training-law-hrpghwicic-con01a'],
#  'are biometrics needed to make a passport': ['training-law-hrpghwicic-pro01b'],
#  'are black plastic assault weapons a dangerous substance?': ['training-law-cphwusbaw-pro04b'],
#  'are blood transfusions in a religious ban': ['test-health-hdond-con04b'],
#  'are borders important': ['training-international-amehwrabre-pro01b'],
#  'are campaigning groups political': ['training-politics-pgghwbnap-pro02a'],
#  'are cars distractions': ['training-science-ncpshwlucpc-pro02a'],
#  'are cartoons hate crimes': ['training-culture-mrrtdnsnhpc-pro01b'],
#  'are cash stamps better than food stamps': ['validation-international-aghwgcprp-con03b'],
#  'are casinos immoral': ['training-law-ucgllghwbg-pro04b'],
#  'are catholics democratic': ['test-international-ssiarcmhb-con01b'],
#  'are catholics safe in ireland': ['test-international-epglghbni-pro03b'],
#  'are celebrities considered private health matters': ['test-politics-cdfsaphgiap-pro02b'],
#  'are celebrities going to get a lawyer': ['training-free-speech-debate-dmagghwrp-pro03a'],
#  'are celebrities important to politics': ['test-politics-epvhbfsmsaop-pro03a'],
#  'are cell phones a public health hazard': ['training-science-ncpshwlucpc-pro01a'],
#  'are cell phones enforceable': ['training-science-ncpshwlucpc-con02b'],
#  'are ceuta and melilla part of spain': ['validation-international-aehbssccamm-con03a'],
#  'are chemical weapons a type of weapon': ['training-international-apdwhwispo-con01b'],
#  'are chemical weapons considered safe?': ['training-international-gpwhuwsocb-con01b'],
#  'are chess game or sports': ['training-sport-ohwico-con01b'],
#  'are chess games viewer friendly': ['training-sport-ohwico-pro04a'],
#  'are child soldiers the product of war': ['test-society-tlhrilsfhwr-con02b'],
#  'are children criminals': ['test-society-tlhrilsfhwr-pro03b'],
#  'are children punished if they fail to instill good values?': ['training-economy-epeeghbpw-con02a'],
#  'are christians allowed to wear cross': ['test-free-speech-debate-nshbcsbawc-pro02b'],
#  'are christians allowed to wear crosses': ['test-free-speech-debate-nshbcsbawc-pro01a'],
#  'are christopher huche indicted': ['training-international-alilhbibaa-pro02b'],
#  'are cigarette addictions addictive': ['training-health-adhgphwfrs-con03b'],
#  'are cigarettes a good food': ['validation-health-dhwiftj-pro02b'],
#  'are cigarettes harmful': ['training-health-adhgphwfrs-pro03b'],
#  'are circuses considered animal welfare': ['validation-environment-rahwbuaosae-pro04b'],
#  'are civil liberties opposed to gun control': ['test-politics-eppghwlrba-con04a'],
#  'are climate models good for climate change': ['test-environment-chbwtlgcc-con02b'],
#  'are coca leaves harmful': ['test-law-thgglcplgphw-pro01a'],
#  'are collective punishment punishments unjust': ['validation-sport-ohwbcvhtmp-con03a'],
#  'are companies legally required to disclose personal data': ['test-digital-freedoms-phwnaccpdt-con02a'],
#  'are conservatives a busted flush': ['training-politics-ghbrphliw-pro02a'],
#  'are corporations restricted from free speech in the constitution?': ['training-free-speech-debate-esdbphwlfsr-con01a'],
#  'are corruption and corruption unacceptable': ['training-economy-egplhbbsa-pro04b'],
#  'are curfews counterproductive': ['training-law-cppfmyhwicc-con03a'],
#  'are curfews effective': ['training-law-cppfmyhwicc-con01a'],
#  'are curfews effective for a crime reduction': ['training-law-cppfmyhwicc-con01a'],
#  'are curfews imposed on young people?': ['training-law-cppfmyhwicc-pro04b'],
#  'are cyber attacks effective': ['test-international-ghwcitca-con03a'],
#  'are cyber attacks escalation': ['training-politics-dwdfiphwut-pro04a'],
#  'are cyber attacks justified by sanctions': ['training-politics-dwdfiphwut-con04a'],
#  'are cyber wars escalations': ['training-politics-dwdfiphwut-pro04a'],
#  'are cyberattacks common': ['test-international-ghwcitca-pro02b'],
#  'are cyberattacks difficult to trace back to': ['test-international-ghwcitca-con01a'],
#  'are daesh terrorists importing terrorists?': ['training-politics-dthbismstw-pro03b'],
#  'are democracy non democratic': ['training-free-speech-debate-ifcidffe-pro02a'],
#  'are democrats considered superdelegates': ['training-politics-pggvhwass-pro02b'],
#  'are designer babies legal': ['training-philosophy-lsgsgfhbpsb-con02b'],
#  'are developing countries developing': ['test-politics-pgsimhwoia-pro03a'],
#  'are divorces the purpose of marriage': ['training-religion-msfhbmoi-pro03a'],
#  'are doctor opting out morally good': ['test-health-hpehwadvoee-con05b'],
#  'are domestic taxes important to the economy': ['training-international-ipiasgfih-con03b'],
#  'are donors able to donate blood to others': ['test-health-hpehwadvoee-con03b'],
#  'are drone attacks a bad thing': ['test-politics-cdmaggpdgdf-con01a'],
#  'are drone attacks necessary': ['training-law-hrpthwuuavs-con02b'],
#  'are drones civilian casualties': ['training-law-hrpthwuuavs-pro01b'],
#  'are drugs already approved in the us': ['training-health-hpessghwgt-con02b'],
#  'are drugs illegal': ['test-law-tahglcphsld-pro06b'],
#  'are drugs safer': ['test-philosophy-apessghwba-con02a'],
#  'are earmarks an accountability system': ['training-politics-appghwace-con02a'],
#  'are earmarks constitutional': ['training-politics-appghwace-con01a'],
#  'are earmarks democratic': ['training-politics-appghwace-pro05a'],
#  'are ebook copies of books dead': ['training-free-speech-debate-bphwpborfs-pro03b'],
#  'are economic sanctions negotiating tools': ['training-international-ghbssbupd-pro04a'],
#  'are election documents useful': ['training-digital-freedoms-gthwpffha-con03b'],
#  'are elections an effective alternative mechanism?': ['test-politics-eppghwgpi-con05b'],
#  'are elections fair to people': ['training-politics-dglvhblmc-con01b'],
#  'are elections necessary or unpopular': ['test-politics-gvhwhnerse-pro03a'],
#  'are elections political or privacy': ['validation-digital-freedoms-phbphnrp-con01a'],
#  'are employees compelled to disclose their condition if they are known to the public?': ['test-health-dhgsshbesbc-con03a'],
#  'are employees protected against bullying': ['test-health-dhgsshbesbc-con02b'],
#  'are encyclopedias written by others': ['training-digital-freedoms-ifakhbwfg-pro02b'],
#  'are endangered animals endangered?': ['test-environment-aiahwagit-pro03a'],
#  'are eta terrorists or states?': ['training-politics-thwnt-con04b'],
#  'are eu national governments effective': ['test-international-ehbfe-pro02b'],
#  'are euro countries in nato': ['training-international-agpwhouhmp-pro05b'],
#  'are eurobonds a burden': ['training-economy-epecfhwie-con01a'],
#  'are eurobonds the same as integration': ['training-economy-epecfhwie-pro01b'],
#  'are european bond payments permanent': ['training-economy-epecfhwie-pro03a'],
#  'are european treaties legally binding': ['validation-international-ephbesnc-pro02b'],
#  'are evictions good or bad': ['training-economy-epiasfihb-pro04b'],
#  'are extraterrestrials contactable': ['training-science-euhwcface-con03a'],
#  'are extraterrestrials hostile': ['training-science-euhwcface-con01a'],
#  'are extremist groups visible': ['training-science-ciidffehwa-con04a'],
#  'are extremists fringe or fringe': ['training-science-ciidffehwa-pro03b'],
#  'are facebook and twitter good or bad': ['test-society-cpisydfphwj-con03b'],
#  'are falkland islands self-supporting': ['training-international-aglilhwccf-pro03b'],
#  'are falklands legitimate': ['training-international-aglilhwccf-con05b'],
#  'are family planning policies right': ['validation-health-pssahbmakfpu-pro03b'],
#  'are family plans gender-based': ['validation-health-pssahbmakfpu-pro01a'],
#  'are federal libraries closed': ['training-free-speech-debate-bphwpborfs-con03b'],
#  'are financial records a political right': ['training-digital-freedoms-gthwpffha-con01a'],
#  'are food labels deceptive': ['training-health-hgwhwilfepe-con02b'],
#  'are forced evictions legal': ['training-economy-epiasfihb-pro02b'],
#  'are forced marriages compulsory': ['test-religion-msgfhwbamec-pro01a'],
#  'are foreign language skills needed': ['training-education-shwmlflcsp-pro03a'],
#  'are foreign policy initiatives coordinated': ['training-international-eghwgepsusc-con03b'],
#  'are former colonies paid reparations': ['test-international-aghbfcpspr-con04a'],
#  "are freedom house's african countries an exception?": ['training-international-astshbghacn-con03b'],
#  'are freedoms intangible or intangible': ['test-law-sdfclhrppph-con02b'],
#  'are ftaa and free trade bad for the environment?': ['test-economy-epegiahsc-con03a'],
#  'are ftp female role models better than male roles': ['training-society-gfhbhsbaa-con01a'],
#  'are gambling illegal': ['training-law-ucgllghwbg-con02b'],
#  'are games violent': ['training-culture-vgcpiyhwrvv-con01a'],
#  'are gay couples legally separated': ['training-religion-msgfhwagcm-con02a'],
#  'are gays against racist speech': ['training-law-aullgsmhwchs-con02b'],
#  'are gender quotas effective': ['test-society-ghbgqeaaems-con03b'],
#  'are gender quotas good or bad': ['test-society-ghbgqeaaems-con01a'],
#  'are generic drugs dangerous': ['test-health-dhghwapgd-con01b'],
#  'are genetic diagnosis considered embryos': ['training-philosophy-lsgsgfhbpsb-pro04b'],
#  'are geneva conventions legal': ['training-law-hrilthbtsbs-con04b'],
#  'are genocide the universal rights': ['training-international-glhrilpws-con02b'],
#  'are gmo food safe': ['test-science-sghwbdgmo-pro01a'],
#  'are gmo foods harmful': ['test-science-sghwbdgmo-pro02b'],
#  'are gmo foods safe': ['test-science-sghwbdgmo-pro01a'],
#  'are government subsidies efficient?': ['validation-economy-ecegthwspc-con01a'],
#  'are grey imports bad for manufacturers': ['validation-economy-beghwarirgg-pro04b'],
#  'are guantanamo bay detainees guilty of terror related crimes or attacks?': ['validation-law-hrilphwcgbd-con03b'],
#  'are gun laws needed to deter violent crimes': ['test-law-cplglghwbhwd-con01a'],
#  'are guns illegally made': ['training-environment-pscisghwbs3-pro02b'],
#  'are hammonds views considered hate speech': ['test-free-speech-debate-ldhwprhs-pro01b'],
#  'are hand free phones dangerous': ['training-science-ncpshwlucpc-con03a'],
#  'are handguns legal in the us': ['test-law-cplglghwbhwd-con02a'],
#  'are hate crime enhancements unjust': ['training-law-cppsmhbhce-pro01a'],
#  'are hate crimes considered a hate crime': ['training-law-cppsmhbhce-pro01b'],
#  'are hate speech a criminal offense': ['training-digital-freedoms-gtdfais-con01b'],
#  'are heads of state african': ['test-law-ralhrilglv-con01b'],
#  'are human rights a presumption': ['training-philosophy-pppghwblro-con02b'],
#  'are human rights considered universal': ['training-international-glhrilpws-con02b'],
#  'are human rights constitutional': ['training-philosophy-iilepphbf-con02a'],
#  'are human rights decisions a decision that a state can make': ['training-science-ncpshwlucpc-con01b'],
#  'are human rights inalienable': ['training-digital-freedoms-gtdfais-pro01a'],
#  "are human rights more moral than the animals'": ['test-philosophy-apessghwba-con01a'],
#  'are human rights prosecutions true': ['test-international-aglhrilhb-con02b'],
#  'are human rights protected under international law': ['training-society-imassirucr-pro01b'],
#  'are human rights universal': ['training-philosophy-iilepphbf-pro03b'],
#  'are humans animals': ['test-environment-assgbatj-con01a'],
#  'are humans morally significant': ['training-environment-aelmmhbahr-pro03b'],
#  'are humans omnivores': ['test-environment-aeghhgwpe-con01b'],
#  'are hydroelectric dams dangerous': ['training-environment-cegwhwbhd-pro03b'],
#  'are ideas physical assets or intangible assets': ['test-health-dhghwapgd-con03b'],
#  'are identity cards a crime': ['training-law-hrpghwicic-con03b'],
#  'are identity cards a crime scene': ['training-law-hrpghwicic-con02a'],
#  'are illegal immigrants protected from the un': ['training-international-glhrsimhw-con03b'],
#  'are illegal immigrants the same as refugees': ['training-international-glhrsimhw-pro04a'],
#  'are immigrant workers richer or poorer': ['training-society-imassirucr-con02b'],
#  'are immigration amnesty laws effective': ['training-society-ihwgaii-con02a'],
#  'are intellectual property intangible': ['training-science-cidfiphwa-con02a'],
#  'are intellectual property rights legal': ['training-science-cidfiphwa-pro02b'],
#  'are internet rights a commodity': ['test-digital-freedoms-aihbiahr-con02a'],
#  'are internet rights considered human rights': ['test-digital-freedoms-aihbiahr-con01a'],
#  'are intolerant schools safe': ['training-religion-frgsbnaofcs-pro02b'],
#  'are investment programs in africa growing': ['test-international-segiahbarr-pro03b'],
#  "are israel's borders indefensible": ['test-international-gmehbisrip1b-con01b'],
#  'are israeli military secrets being published': ['training-free-speech-debate-fchblmdakw-con01b'],
#  'are israeli settlements illegal': ['test-law-rmelhrilhbiw-pro01a'],
#  'are journalists responsible for the press': ['training-free-speech-debate-dmagghwrp-con02b'],
#  'are junk food schools healthy': ['test-health-hgwhwbjfs-con03b'],
#  'are jury tampering punishable by jail': ['test-philosophy-eppphwlrtjs-pro02b'],
#  'are kids exposed to drugs or alcohol': ['test-culture-mmctyshwbcp-pro05b'],
#  'are kids sexually active': ['validation-education-shwmsems-pro03a'],
#  'are kids using phones at risk': ['validation-science-cpecshmpj-con03a'],
#  'are kings or queens defiant': ['training-culture-tpghwam-con01b'],
#  'are labour standards the same as development': ['test-economy-epehwmrbals-con01b'],
#  'are landmines a tool of war': ['training-international-gpwhuwsocb-pro01a'],
#  'are landmines legal': ['training-international-gpwhuwsocb-con02a'],
#  'are landmines legal in ottawa': ['training-international-gpwhuwsocb-pro01b'],
#  'are languages beneficial to the economy': ['training-education-shwmlflcsp-pro02b'],
#  'are learning disabilities protected by human rights': ['training-environment-aelmmhbahr-pro05a'],
#  'are legally owned firearms legal': ['training-law-cplghwap-pro03b'],
#  'are long hours unfair': ['validation-religion-cfhwksdr-con03a'],
#  'are lords conservative': ['test-politics-gvhbhlsbr-pro02b'],
#  'are low cost health care models being created': ['validation-health-hpiahbps-con01b'],
#  'are lower house elections undemocratic': ['training-politics-ghbuhsbap-pro01b'],
#  'are mandatory sentences considered a deterrent effect': ['training-law-phsms-pro02b'],
#  'are marijuana illegal under the narcotics convention': ['test-law-thgglcplgphw-pro03b'],
#  'are married couples entitled to welfare': ['training-religion-msgfhwagcm-pro02b'],
#  'are married parents actually better for kids': ['training-society-gfhbhsbaa-pro02b'],
#  'are married parents really better for children': ['training-society-gfhbhsbaa-pro02b'],
#  'are married priests allowed to serve as catholic priests': ['training-religion-chwrrcptvc-con02b'],
#  'are mauritius and the chagossians second class citizens': ['validation-international-ahwrcim-con02b'],
#  'are mauritius chagos arbitrary': ['validation-international-ahwrcim-pro04b'],
#  'are mayors elected directly': ['test-politics-lghwdecm-pro03a'],
#  'are meats bad for you': ['test-environment-aeghhgwpe-pro03a'],
#  'are men allowed to play in sports leagues': ['training-sport-mosgtshwawcs-con04a'],
#  'are mercenaries legal in africa': ['training-international-apdwhbpa-pro02a'],
#  'are mercenaries still prevalent': ['training-international-apdwhbpa-con02a'],
#  'are microfinances considered debt': ['test-economy-fiahwpamu-pro05b'],
#  'are migrants more likely to return to developed countries': ['test-politics-pgsimhwoia-con03a'],
#  'are migrants protected by social protection': ['training-international-gsimhbnws-pro01a'],
#  'are migration policy and rights international law?': ['training-international-gsimhbnws-con02a'],
#  'are military secrets classified': ['training-free-speech-debate-fchbnhampi-con03b'],
#  'are minor errors a criminal matter': ['training-free-speech-debate-radhbrr-pro02b'],
#  'are minorities protected': ['training-international-alhrpsgmhb-con01b'],
#  'are missile defenses effective?': ['test-science-dssghsdmd-con01b'],
#  'are missiles considered conventional warfare': ['test-science-dssghsdmd-con01b'],
#  'are mlb catchers injured': ['test-sport-tshbmlbscac-pro03a'],
#  'are mobile phone cards a good idea': ['training-law-hrpghwicic-con04b'],
#  'are mobile phones bad for the environment': ['validation-science-cpecshmpj-con02a'],
#  'are mobile phones damaging to environment': ['validation-science-cpecshmpj-con02a'],
#  'are mobile phones illegal in cars': ['training-science-ncpshwlucpc-pro02b'],
#  'are monarch head on british money': ['test-politics-cpegiepgh-con03b'],
#  'are monarchs human': ['training-culture-tpghwam-con01b'],
#  'are monopolies socially transferable skills': ['training-economy-epehwacbr-con03b'],
#  'are moocs a money-making platform': ['test-education-egtuscpih-con01a'],
#  'are moralities an evolutionary issue': ['training-science-gsehbehdc-con04b'],
#  'are most people going to be away from work on saturday': ['validation-religion-cfhwksdr-con01b'],
#  'are multiple vaccines harmful': ['training-health-dhgamvs-pro02a'],
#  'are mumps vaccines effective?': ['training-health-dhgamvs-pro01a'],
#  'are muslim women obliged to wear underwear': ['test-politics-grcrgshwbr-pro01b'],
#  'are muslims extremists': ['training-science-ciidffehwa-con05a'],
#  'are native speakers needed': ['training-society-negsimhwso-con03a'],
#  'are nato members in icc': ['training-law-ilhwpoa9apus-con02b'],
#  'are natural monopolies broken down': ['training-economy-epehwacbr-con03b'],
#  'are network bandwidth plans free': ['test-digital-freedoms-eifdfaihs-con01a'],
#  'are newspaper revenues stable?': ['training-culture-mmchbnatp-pro04b'],
#  'are newspapers financially unviable': ['training-culture-mmchbnatp-pro04a'],
#  'are newspapers linear': ['training-culture-mmchbnatp-pro01b'],
#  'are newspapers paper environmentally friendly': ['training-culture-mmchbnatp-pro03b'],
#  'are norway and switzerland in eu': ['training-international-ehbsansaje-pro02b'],
#  'are norway and switzerland part of europe': ['training-international-ehbsansaje-pro05a'],
#  'are nuclear energy stations green': ['training-environment-cephbesane-pro02b'],
#  'are nuclear plants considered dangerous': ['training-environment-cephbesane-pro03a'],
#  'are nuclear plants harmful': ['training-environment-cehwirtrnp-pro03b'],
#  'are nuclear plants poisonous': ['training-environment-cehwirtrnp-pro03a'],
#  'are nuclear plants safe': ['training-environment-ogecephwgn-con04b'],
#  'are nuclear power plants green': ['training-environment-cephbesane-pro02b'],
#  'are nuclear power stations really green': ['training-environment-cephbesane-pro02b'],
#  'are nuclear weapons an option in war': ['training-politics-whwanw-pro01b'],
#  'are nuclear weapons deployed in the field': ['validation-politics-dhwdtnw-con01b'],
#  'are nuclear weapons destructive': ['training-politics-whwanw-pro01a'],
#  'are nuclear weapons harmful': ['training-politics-whwanw-pro01a'],
#  'are nuclear weapons illegal': ['training-politics-whwanw-pro04a'],
#  'are nuclear weapons protected by international treaties': ['training-politics-whwanw-pro04b'],
#  'are nuremburg convictions icty': ['training-law-hrilhwpwc-con01b'],
#  'are offensive acts legal in the us': ['training-international-glilhbmai-pro03a'],
#  'are oil pipelines good': ['training-environment-cephwcear-con02b'],
#  'are older employees more attractive': ['training-economy-epeshwimra-con02a'],
#  'are oligarchic countries a democracy': ['training-politics-oamepdgtwh-con04a'],
#  'are olympics in africa': ['training-economy-epsosghbsas-con03a'],
#  'are online gambling regulated': ['test-economy-beplcpdffe-pro04b'],
#  'are open markets good or bad': ['test-economy-eptpghdtre-con02b'],
#  'are open primaries predictable': ['training-politics-pggvhbopam-pro04b'],
#  'are open source projects dangerous': ['test-digital-freedoms-dfiphbgs-con03a'],
#  'are openstreetmap and google maps considered to be a building block?': ['training-digital-freedoms-pidfakhwnfawn-pro03a'],
#  'are opinion polls illegal': ['training-politics-pggvhbophd-con01b'],
#  'are opinion polls useful': ['training-politics-pggvhbophd-con05b'],
#  'are organised religion and the state the same': ['training-philosophy-eppprfmhb-pro03a'],
#  'are organs considered to be inherently dangerous': ['test-health-hpehwadvoee-con02a'],
#  'are orphan copies of work the same as original works': ['test-culture-ascidfakhba-pro02b'],
#  'are out of town malls desirable to shoppers': ['training-environment-pwshwdotsc-pro03b'],
#  'are painters learning by doing': ['training-culture-aeuhbdcaal-pro02a'],
#  'are pangolins endangered': ['test-environment-aiahwagit-pro03b',
#   'test-international-iiahwagit-pro03b'],
#  'are parents allowed to pick their kids': ['training-philosophy-lsgsgfhbpsb-pro03b'],
#  'are parents legally responsible for their kids': ['validation-philosophy-ehbidachsb-pro03b'],
#  'are parents responsible for homeschooling': ['training-education-egtyhshs-con04a'],
#  'are partial births unjustifiable': ['test-health-ppelfhwbpba-con02b'],
#  'are patents a monopoly': ['training-science-cidfiphwa-con04b'],
#  'are patents legally free': ['test-health-dhghwapgd-pro04b'],
#  'are people always wise about what they do': ['test-philosophy-elkosmj-con02a'],
#  'are people at brixton riots racist': ['training-law-cpshbsdcc-pro03a'],
#  'are people forced to study languages': ['training-education-shwmlflcsp-pro06a'],
#  'are people guilty of capital punishment more likely to die in jail': ['training-law-phsdpww-con02b'],
#  'are people in africa under investigation': ['training-international-alilhbibaa-pro01a'],
#  'are petro states government democracy': ['test-politics-gvhwhnerse-pro04a'],
#  'are pharmaceuticals needed': ['test-health-dhiacihwph-pro02a'],
#  'are pigs owned by a human': ['training-environment-aelmmhbahr-con03a'],
#  'are playoffs more likely to be run in the afp': ['training-sport-tshwipclaf-con02a'],
#  'are playoffs really a bad idea?': ['training-sport-tshwipclaf-con01a'],
#  'are pmcs disciplined': ['test-politics-dhwem-pro01b'],
#  'are police police armed': ['training-law-cplghwap-con02b'],
#  'are politicians treated as having no right to privacy?': ['validation-digital-freedoms-phbphnrp-con02a'],
#  'are pornographic actresses legitimate': ['test-society-mmcpsgfhbf-con01b'],
#  'are poverty and social mobility equal': ['training-philosophy-lsfhwnhc-pro04b'],
#  'are previous convictions disclosed': ['test-law-cplgpshwdp-pro05b'],
#  'are prison facilities politically unacceptable': ['training-law-apslpsyhwbbc-pro04a'],
#  'are privacy and protection important to society?': ['training-law-cplghrhwrgo-pro01b'],
#  'are private companies competitive': ['test-politics-dhwem-pro02b'],
#  'are private language teachers needed': ['training-education-shwmlflcsp-con01b'],
#  'are pronouncements morally important': ['training-digital-freedoms-fehbwdsot-pro02b'],
#  'are public opinion the same as europe house believes?': ['test-international-ehbfe-con03b'],
#  'are public opinion views wrong': ['training-digital-freedoms-gthbtsbp-con02b'],
#  'are published requests accountable?': ['training-digital-freedoms-gthbtsbp-pro03a'],
#  'are pubs smoking': ['test-economy-bhahwbsps-con03b'],
#  'are puerto ricans exempt from tax breaks': ['training-politics-glgvhbprss-pro02b'],
#  'are punishments fair to everyone': ['test-law-phwmfri-con02b'],
#  'are quotas binding': ['test-international-iighbopcc-pro01b'],
#  'are quotas important': ['training-politics-oapglvsghw-con01a'],
#  'are quotas in africa effective': ['training-politics-oapglvsghw-con01a'],
#  'are reality shows corrupting': ['training-culture-cgmmcthbrt-pro03b'],
#  'are reality shows harmful': ['training-culture-cgmmcthbrt-pro03a'],
#  'are reality shows real': ['training-culture-cgmmcthbrt-pro04b',
#   'training-culture-cgmmcthbrt-pro04a'],
#  'are reconciliation commissions a mask': ['training-law-ilppghsuta-con02a'],
#  'are refugee rights moral or legal': ['test-society-simhbrasnba-con01b'],
#  'are refugees in the gulf': ['training-international-mesimhbgs-con02a'],
#  'are registrars supposed to be impartial': ['training-religion-msgfhwagcm-pro03b'],
#  'are religions and gods': ['test-religion-frghbbgi-pro02b'],
#  'are remittances good for poverty': ['training-economy-epeghwrar-pro03b'],
#  'are remittances good for the taxpayer': ['training-economy-epeghwrar-pro01a'],
#  'are remittances worth it': ['training-economy-epeghwrar-con03b'],
#  'are repatriated illegal immigrants safer': ['training-international-glhrsimhw-pro02b'],
#  'are reproductive cloning laws illegal': ['training-health-hgfhwbhc-pro03b'],
#  'are republican primaries a lie': ['training-economy-egppgghwgo-pro03b'],
#  'are republican primaries already going to start': ['training-economy-egppgghwgo-pro03b'],
#  "are russia's leaders democratic or not": ['test-politics-oepghbrnsl-pro01b'],
#  'are russian troops allowed to cross the international border': ['training-international-egilpwhbrh-con02a'],
#  'are russians able to hold onto power': ['validation-politics-glvhwetleb-pro03b'],
#  'are russians enraged by joining nato': ['training-international-epdhwenmga-pro01b'],
#  'are russians strong': ['test-politics-oepghbrnsl-pro04b'],
#  'are sadomasochistic rules legal': ['training-law-tllgrhwds-con02b'],
#  'are sanctions considered illegal': ['training-politics-dwdfiphwut-con01a'],
#  'are sanctions effective': ['training-international-ghbssbupd-con04a'],
#  'are sats objective': ['test-education-tuhwastua-con02b'],
#  'are sats standardized tests': ['test-education-tuhwastua-con01a'],
#  'are school disciplinary tactics a useful tool': ['training-education-eghbpsbhrt-con03b'],
#  'are school phones a distraction': ['validation-science-cpecshmpj-con01b'],
#  'are schools accused of bullying': ['training-law-ueegllghwhsl-con04b'],
#  'are schools aimed at schools': ['training-education-egpeupdw-con01b'],
#  'are schools and homes similar': ['training-education-egtyhshs-pro02b'],
#  'are schools considered poor': ['training-economy-epeeghbpw-con03a'],
#  'are scientific scientists religious': ['test-religion-frghbbgi-pro03b'],
#  "are scotland's seats safe": ['training-politics-viwvfpps-con01b'],
#  'are second generation immigrants free to learn language': ['training-society-negsimhwso-con01b'],
#  'are security measures a good idea': ['test-philosophy-pphbclsbs-pro02a'],
#  'are serbs suffering right now in kosovo': ['training-international-ggvhwrkis-pro03b'],
#  'are sex workers in africa allowed to work': ['training-health-dssiahwlswo-con02b'],
#  'are sexual orientation grounds for asylum?': ['validation-society-gihbsosbcg-con04a'],
#  'are sexually abusive women considered catholics': ['training-religion-chwrrcptvc-pro04b'],
#  'are seychelles sovereign': ['test-international-iwiaghbss-con03a'],
#  'are seychelles territories a viable government': ['test-international-iwiaghbss-con03b'],
#  'are siblings of criminals evicted': ['training-law-lgpcpao-pro04b'],
#  'are skin whitening products a colonial idea': ['test-culture-mmciahbans-pro03b'],
#  'are slaughters worse than religious slaughter?': ['training-environment-ahwbsawhnbsf-con02b'],
#  'are slums a challenge': ['training-economy-epiasfhbac-pro01b'],
#  'are slums the problem of africa': ['training-economy-epiasfhbac-pro01b'],
#  'are smartphones widely available?': ['test-international-siacphbnt-con02a'],
#  'are social responsibility systems becoming increasingly complex': ['validation-economy-ecegthwspc-con02a'],
#  'are sovereign funds protected by government regulation': ['training-economy-feghwarasw-pro05a'],
#  'are sovereign wealth funds transparent': ['training-economy-feghwarasw-pro03a'],
#  'are space missions safe': ['training-science-uhbmsf-pro04b'],
#  'are studies conclusive': ['training-health-dhgamvs-pro02b'],
#  'are subsidies efficient': ['validation-economy-ecegthwspc-pro02b',
#   'validation-economy-ecegthwspc-con01a'],
#  'are subsidies unfair': ['validation-international-aghwgcprp-pro01b'],
#  'are suicides morally unrestrained': ['test-health-dhpelhbass-con02a'],
#  "are surgery necessary to end someone's life": ['test-health-dhpelhbass-con03b'],
#  'are surveillance necessary': ['validation-international-gsidfphb-con01b'],
#  'are surveillance technologies acceptable': ['training-free-speech-debate-ifcidffe-con04b'],
#  'are swfs good for emerging economies': ['training-economy-feghwarasw-con01b'],
#  'are switzerland and norway united in the european union': ['training-international-ehbsansaje-con01a'],
#  'are talib': ['training-international-amehbncag-pro02b'],
#  'are taliban mainly pashtun': ['training-politics-dtwhbnhsa-con04a'],
#  'are taliban oppressive': ['training-international-amehbncag-con01b'],
#  'are tax cuts a stimulus': ['training-philosophy-ppphwrbtcw-con01b'],
#  'are taxed on income': ['training-politics-vhwlva1-pro02b'],
#  'are teachers paid very highly': ['validation-economy-eehwpsstbm-pro03a'],
#  'are teachers police officers': ['training-law-aegtlcpsyhwa-con03a'],
#  'are teachers protected from sexual harassment': ['training-law-aegtlcpsyhwa-con04b'],
#  'are temples a public event': ['training-international-ahwvys-pro03b'],
#  'are term limits unfair to the state legislature': ['training-philosophy-eppppghwe-con03a'],
#  'are terrorism recruitment tools?': ['training-law-hrilthbtsbs-pro03b'],
#  'are terrorists considered prisoner of war': ['training-law-hrilthbtsbs-con04a'],
#  'are terrorists in war': ['training-law-hrilthbtsbs-con01a'],
#  'are the american flags important': ['validation-free-speech-debate-bphwpbsas-pro01b'],
#  'are the cartoons racist': ['training-culture-mrrtdnsnhpc-pro01b'],
#  'are the chagos islands a us government': ['validation-international-ahwrcim-con01b'],
#  'are the chagos islands permanent inhabitants': ['validation-international-ahwrcim-pro04a'],
#  'are the chagos islands under us control': ['validation-international-ahwrcim-con01a'],
#  'are the dsi terrorists': ['training-politics-dthbismstw-pro03a'],
#  'are the europe 15 member states in the united states': ['training-international-ehbesefe-con01a'],
#  'are the european commissions democratic': ['training-economy-ecegiehbe-pro01a'],
#  'are the falkland islands a democracy': ['training-international-aglilhwccf-con05a'],
#  'are the gulf states an oppression or a civil war?': ['training-international-mesimhbgs-con01a'],
#  'are the intelligence agencies under civilian control': ['test-digital-freedoms-efsappgdfp-con01b'],
#  'are the irish united or republican': ['test-international-epglghbni-con03a'],
#  'are the lords considered a democracy': ['test-politics-gvhbhlsbr-pro04b'],
#  'are the minerals being sold smuggled out of democratist republic of the congo?': ['training-international-aghbuidrch-con02a'],
#  'are the occupy protesters socialist or socialist': ['test-philosophy-pppgshbsd-pro01a'],
#  'are the official languages of the european union': ['training-international-ehbeusaswl-con02b'],
#  'are the planets destroyed by manned space flight': ['training-science-uhbmsf-pro04a'],
#  'are the poachers the armed ones in the arm race': ['test-environment-aiahwagit-pro02b'],
#  'are the pre 1967 borders indefensible': ['test-international-gmehbisrip1b-con01b'],
#  'are the sanctions effective against north korea?': ['training-international-ghbssbupd-con01a'],
#  'are the settlements in the west bank two states': ['training-international-mehbcbiapts-con02a'],
#  'are the treaties constitutional': ['validation-international-ephbesnc-pro02b'],
#  'are the views of the public unrepresented in political debate': ['training-politics-pgglgvhciu-pro04a'],
#  'are the west bank borders de facto?': ['test-law-rmelhrilhbiw-con04b'],
#  'are there any benefits to gmo seeds': ['test-science-sghwbdgmo-pro02b'],
#  'are there any ethical issues associated with killing a human': ['test-philosophy-apessghwba-pro02b'],
#  'are there any financial incentives for poor people': ['validation-society-gfhbcimrst-con05a'],
#  'are there any religions in the world that are persecuted': ['training-religion-fmshbrdmhg-pro03a'],
#  'are there any ways of confirming a degree?': ['test-education-egtuscpih-con02b'],
#  'are there barriers to entrepreneurship in africa': ['test-international-siacphbnt-con01a'],
#  'are there cases to deter a regime': ['training-international-glhrilhbunh-con04b'],
#  'are there constitutional problems in a usa': ['training-international-epdghwcseu-con01a'],
#  'are there countries with self-determination': ['test-law-ilppppghb-pro04b'],
#  'are there dangers involved in exclusivity of faith': ['training-education-egtyhshs-pro06b'],
#  'are there democratic elections in eu': ['training-international-epvepesio-con03b'],
#  'are there democratic institutions in egypt': ['training-politics-oamepdgtwh-pro01a'],
#  'are there ever any ira suicide bombers': ['training-politics-ogmepthbeuao-con03b'],
#  'are there harsh penalties for dealing': ['test-international-iiahwagit-pro05b'],
#  'are there icc courts to deal with criminal cases': ['training-international-alilhbassw-con01b'],
#  'are there laws to disclose prior convictions': ['test-law-cplgpshwdp-pro03b'],
#  'are there more casualties than natural disasters': ['training-environment-cpiahwdwf-pro01b'],
#  'are there no laws against self incrimination': ['training-law-tllgrhwds-pro02b'],
#  'are there police forces?': ['training-law-cplghwap-pro01a'],
#  'are there rules for recording music': ['training-culture-amcghbmgvaw-con01b'],
#  'are there still extreme weather events and climate change?': ['training-environment-cpiahwdwf-pro01b'],
#  'are there too late consequences for climate change?': ['test-environment-chbwtlgcc-pro04b'],
#  'are they government policies or government regulation': ['test-law-sdfclhrppph-pro01b'],
#  'are they promoting an adoption': ['validation-society-fyhwscdcj-pro03b'],
#  'are they safe in northern ireland': ['test-international-epglghbni-pro03b'],
#  'are they the worst of the worst?': ['training-law-phsdpww-con04b'],
#  'are think tanks political': ['training-politics-pggdfakhwf-pro01b'],
#  'are think tanks public': ['training-politics-pggdfakhwf-pro05b'],
#  'are think tanks transparent': ['training-politics-pggdfakhwf-pro01b'],
#  'are think tanks unbiased': ['training-politics-pggdfakhwf-pro02a'],
#  'are tibetans a minority': ['training-law-railhbtsbis-pro02a'],
#  'are tibetans minority': ['training-law-railhbtsbis-pro02a'],
#  'are tragedies logically explained?': ['training-religion-fmshbrdmhg-con02b'],
#  'are trans fats bad for your health': ['training-health-hgwhwbutffs-con02b'],
#  'are trans fats harmful to humans': ['training-health-hgwhwbutffs-pro02a'],
#  'are trans fats safe': ['training-health-hgwhwbutffs-pro03b'],
#  'are trans fats unhealthy': ['training-health-hgwhwbutffs-con01b'],
#  'are trans fats unsafe': ['training-health-hgwhwbutffs-pro01a',
#   'training-health-hgwhwbutffs-pro03a'],
#  'are treaties constitutional': ['validation-international-ephbesnc-con01a'],
#  'are troops needed for afghanistan': ['training-politics-dtwhbnhsa-con01b'],
#  'are turkey and greece a european country': ['test-international-emephsate-pro03b'],
#  'are turkey democracy': ['test-international-emephsate-con02b'],
#  'are turkey non-european': ['test-international-aegmeppghw-con01b'],
#  'are two languages good for your brain': ['training-education-shwmlflcsp-pro06b'],
#  'are uavs unnecessarily dangerous': ['training-law-hrpthwuuavs-con02b'],
#  'are uk police unions important': ['training-law-cplghwap-con01b'],
#  'are unhealthy foods a result of inflation': ['test-economy-thhghwhwift-pro03a'],
#  'are universal health care inefficient': ['training-health-fhhphwisu-con01b'],
#  'are universities financed by a tax': ['test-education-pteuhwfphe-con02a'],
#  'are universities required to pay for degrees': ['training-culture-aeuhbdcaal-con03b'],
#  'are university scholarly resources the key to global economic growth': ['test-education-udfakusma-pro01a'],
#  'are university taxing': ['test-education-pteuhwfphe-con03b'],
#  'are unresolved housing crises an example of poverty': ['training-economy-epiasfihb-con05a'],
#  'are urban poor more vulnerable': ['validation-health-hpiahbps-pro03b'],
# ...
#  'can a ban on the crucifix cause a problem': ['test-politics-grcrgshwbr-con01a'],
#  'can a baseball catcher block the plate': ['test-sport-tshbmlbscac-pro04a'],
#  'can a book be published in germany': ['training-free-speech-debate-fkhsdsbpmk-pro01a'],
#  'can a business use copyright on a vehicle': ['validation-economy-beghwarirgg-con02b'],
#  'can a candidate support a party': ['training-politics-pggvhbopam-pro03b'],
#  'can a catcher block a run': ['test-sport-tshbmlbscac-pro04a'],
#  'can a celebrity be accused of discrimination?': ['test-politics-epvhbfsmsaop-pro02b'],
#  'can a celibate priest become a married priest': ['training-religion-chwrrcptvc-con01b'],
#  'can a child be considered capable?': ['validation-philosophy-ehbidachsb-con01b'],
#  'can a christian dress differently': ['test-free-speech-debate-nshbcsbawc-pro03b'],
#  'can a christian registrar be demoted': ['training-religion-msgfhwagcm-pro03b'],
#  'can a civil society democratize political power in africa': ['training-international-algsfmhbc-con02b'],
#  'can a cleric explain a tragic death': ['training-religion-fmshbrdmhg-con02b'],
#  'can a company use a patent': ['test-society-asfhwapg-pro02a'],
#  'can a contest be a cause of political contention?': ['training-politics-pggvhbopam-pro05b'],
#  'can a country join the eu': ['training-international-ehbesefe-pro02b'],
#  'can a country lose unsc': ['training-international-eghwgepsusc-pro05b'],
#  'can a country not accept remittances': ['training-society-imassirucr-pro04b'],
#  'can a democracy have international interference': ['training-digital-freedoms-fehwufafra-con01a'],
#  'can a dictatorship be a democracy?': ['test-economy-bepighbdb-pro03b'],
#  'can a disqus ban make a suicide': ['validation-science-ihbrapisbpl-con03b'],
#  'can a doctor proscribe an unapproved substance': ['training-health-hpessghwgt-con02b'],
#  'can a drug company have a status quo': ['training-health-hpessghwgt-pro02b'],
#  'can a drug company keep the duty on a drug': ['training-health-hpessghwgt-con03b'],
#  'can a drug rep do a clinical trial': ['training-health-hpessghwgt-con04b'],
#  'can a family be adopted': ['training-society-gfhbhsbaa-con02a'],
#  'can a father be deprived of a child with a large number': ['training-philosophy-lsgsgfhbpsb-pro03a'],
#  'can a federal union coexist with a veto?': ['validation-international-ehwlavpiems-pro03b'],
#  'can a female athlete compete against men': ['training-sport-mosgtshwawcs-pro01a'],
#  'can a generic drug be safe': ['test-health-dhghwapgd-con01a'],
#  'can a harsh prison environment help criminals': ['validation-law-cpphwmpfcp-pro03a'],
#  'can a healthcare worker be exposed to hiv': ['test-health-dhgsshbesbc-pro03a'],
#  'can a jd help a student get an mba': ['training-education-ulghblqwc-pro02b'],
#  'can a journalist be a celebrity': ['training-free-speech-debate-fsaphwacsl-pro02a'],
#  'can a judge be required to provide information when preparing a plea bargain?': ['training-law-phsms-pro01b'],
#  'can a judge reassess evidence from the first trial video': ['test-law-lghwpcctcc-pro02a'],
#  'can a jury be impartial': ['test-philosophy-eppphwlrtjs-pro03a'],
#  'can a jury overturn a verdict': ['test-philosophy-eppphwlrtjs-pro05b'],
#  'can a just war be legal': ['training-international-glilhbmai-pro03b'],
#  'can a lame duck have a second term': ['training-philosophy-eppppghwe-pro04b'],
#  'can a large retailer exploit consumers': ['training-economy-beghwprsci-con01b'],
#  'can a law be passed that limits the ability to stop smoking': ['training-health-ahghhwdsas-con01a'],
#  'can a law degree be a jd': ['training-education-ulghblqwc-pro02b'],
#  'can a law graduate be a lawyer': ['training-education-ulghblqwc-pro05a'],
#  'can a legislature impose a term limit': ['training-philosophy-eppppghwe-con04b'],
#  'can a loss leader benefit a low income consumer': ['training-economy-beghwprsci-con02b'],
#  'can a marriage be arranged': ['test-religion-msgfhwbamec-con03b'],
#  'can a mental person be force fed': ['training-health-mchdhgwhwff-pro02a'],
#  'can a mmr vaccination hurt people?': ['training-health-dhgamvs-con02a'],
#  'can a monogamous couple be conscientious to limit procreation': ['test-international-ssiarcmhb-pro04b'],
#  'can a monogamous relationship be a stable relationship?': ['training-religion-msfhbmoi-con01a'],
#  'can a mother terminate pregnancy': ['training-philosophy-tgppelhbwrc-pro04a'],
#  'can a myps monitor something': ['test-digital-freedoms-eifdfaihs-con02a'],
#  'can a negotiation get a result of the release of prisoners': ['training-politics-thwnt-con03b'],
#  'can a nuclear power be used in pakistan': ['training-politics-whwanw-pro03a'],
#  'can a palestinian be returned to israel': ['training-international-mehrilsim-con03a'],
#  'can a parent get a college entrance exam': ['test-education-tuhwastua-pro02b'],
#  'can a parent home school their child': ['training-education-egtyhshs-pro05a'],
#  'can a parent withdraw their child from school': ['training-education-egtyhshs-con01b'],
#  'can a patient with a smoking habit have a smear': ['training-health-ahghhwdsas-pro05a'],
#  'can a peace treaty get rid of north korea': ['test-politics-oapdhwinkp-pro03b'],
#  'can a person adopt a gay child?': ['training-society-gfhbhsbaa-pro03b'],
#  'can a person avoid cyberbullying': ['training-digital-freedoms-sfydfphwap-pro01a'],
#  'can a person be cloned and eugenics': ['training-health-hgfhwbhc-con02b'],
#  'can a person legally donate organs': ['test-health-hdond-pro04a'],
#  'can a person organize an event or protest': ['training-digital-freedoms-aihbied-con02b'],
#  'can a pharmaceutical be advertised': ['training-health-bhhghwapc-con02a'],
#  'can a player be in a heat': ['training-sport-tshwm2fwcw-pro01a'],
#  'can a politician be lame': ['training-philosophy-eppppghwe-con02a'],
#  'can a product be marketed in uk': ['training-health-adhgphwfrs-pro02b'],
#  'can a progressive tax system benefit the wealthy': ['test-economy-thsptr-con03a'],
#  'can a progressive tax system create a burden on the more wealthy': ['test-economy-thsptr-con03a'],
#  'can a referendum affect the political system': ['training-politics-pgglgvhciu-pro05a'],
#  'can a regime be oppressed with internet rights': ['training-digital-freedoms-fehbwdsot-con02a'],
#  'can a relationship between a gay man and a l.a. lebian man be sex': ['training-religion-chwccaogalp-con02b'],
#  'can a renegotiation deal be legally binding': ['training-politics-oepvhwvseacd0-con03a'],
#  "can a rogue leader get obama's permission to host foreign leaders?": ['training-international-ghbowramrlw-con02a'],
#  'can a scientist harm animals ethically': ['test-philosophy-apessghwba-pro05b'],
#  'can a scientist test animals': ['test-environment-assgbatj-con05b'],
#  'can a sex breach of consent be criminally': ['training-law-tllgrhwds-pro03b'],
#  'can a sex provider terminate contracts': ['training-law-lgsghwlp-pro03a'],
#  'can a sexual provider be legally obligated to keep their sexual relationship': ['training-law-lgsghwlp-pro03a'],
#  'can a small business be protected from government tax cuts': ['training-philosophy-ppphwrbtcw-con02b'],
#  'can a smoker quit smoking': ['test-economy-bhahwbsps-pro03a'],
#  'can a smoking ban be enforced': ['test-economy-bhahwbsps-con01b'],
#  'can a spell of jail prevent radicalisation': ['training-free-speech-debate-ifdffehw-pro01b'],
#  'can a state suppress historical events?': ['training-free-speech-debate-efsdfkhwsds-con03b'],
#  'can a terrorist organization achieve its objectives by violence': ['training-politics-thwnt-con02b'],
#  'can a think tank have an independent funder': ['training-politics-pggdfakhwf-con01a'],
#  'can a think tank say who their funder is': ['training-politics-pggdfakhwf-con01b'],
#  'can a title to a property benefit a woman': ['training-international-ipiasgfih-con04a'],
#  'can a translator do the translation': ['training-international-ehbeusaswl-con03a'],
#  'can a tv company ban sexist advertising': ['test-culture-mmctghwbsa-pro02b'],
#  'can a u.s. state grant palestinians a statehood': ['validation-international-ggsurps-con04a'],
#  'can a united states pass a treaty': ['validation-international-ehwlavpiems-pro02a'],
#  'can a video game help with attention deficit disorder': ['training-culture-vgcpiyhwrvv-pro03b'],
#  'can a witness be televised': ['test-law-umtlilhotac-pro02b'],
#  'can a woman choose a job after a cross': ['test-free-speech-debate-nshbcsbawc-con01a'],
#  'can a woman represent a division in the government': ['training-politics-oapglvsghw-con02b'],
#  'can a woman take their primary asset to gain credit': ['training-international-ipiasgfih-pro03b'],
#  'can a worker leave after the work permit expired': ['training-international-glhrsimhw-con01b'],
#  'can acsos democratically bind the people they represent?': ['training-international-algsfmhbc-pro01b'],
#  'can adolescent misbehave': ['validation-science-ihbrapisbpl-pro02a'],
#  'can advertising be banned': ['test-culture-mmctghwbsa-con01b',
#   'training-health-mthwhwbpd-con02a'],
#  'can affirmative action be taken to make society a meritocracy?': ['test-education-usuprmhbu-con01b'],
#  'can afghanistan get aid from us': ['training-politics-dtwhbnhsa-con03a'],
#  'can african nations ban dangerous products': ['test-culture-mmciahbans-con01b'],
#  'can african states set up their own court': ['training-international-alhrilhwca-pro02b'],
#  'can amateur baseball players have collisions': ['test-sport-tshbmlbscac-con03b'],
#  'can an ICC be used as an enforcement force': ['validation-law-hrilhbiccfg-con03b'],
#  'can an abuser claim that he was in his care': ['training-law-aegtlcpsyhwa-con04b'],
#  'can an acc or eu have its own judiciary': ['training-international-alhrilhwca-pro04b'],
#  'can an act of revenge be illegal': ['training-free-speech-debate-gfsdifscp-pro02b'],
#  'can an adult harmed child be legally considered incapable': ['validation-philosophy-ehbidachsb-con01b'],
#  'can an african criminal court deal with corruption': ['training-international-alhrilhwca-pro04a'],
#  'can an amnesty be granted under laws': ['test-law-sdiflhrdffe-con04b'],
#  'can an animal be tested': ['test-science-eassgbatj-con05b'],
#  'can an arming teacher be regulated': ['training-law-aegtlcpsyhwa-con04a'],
#  'can an army be formed in europe': ['training-international-epdghwcseu-pro05b'],
#  'can an earmark be used to provide tax breaks': ['training-politics-appghwace-con02b'],
#  'can an education teacher provide breakfast': ['test-education-pshhghwpba0-pro04b'],
#  'can an employee be fired for having hiv': ['test-health-dhgsshbesbc-pro02a'],
#  'can an energy dam be used for power': ['training-environment-eegwiahbe-pro01a'],
#  'can an immigration amnesty be done for illegal immigrants?': ['training-society-ihwgaii-con01b'],
#  'can an independent nation be charged with a war crime': ['training-international-alilhbassw-con03b'],
#  'can an international agency regulate migrants rights': ['training-international-gsimhbnws-pro03b'],
#  'can an international organization fall into disuse': ['training-international-alhrilhwca-con02b'],
#  'can an ira suspect be captured alive': ['validation-law-hrilppwhb-con02b'],
#  'can an mrr cause autism?': ['training-health-dhgamvs-pro02a'],
#  'can an offender be in school': ['training-law-lgpisyhwhcdt-con02b'],
#  'can an organ be used in euthanasia': ['test-health-hpehwadvoee-pro04a'],
#  'can animal research be banned': ['test-philosophy-apessghwba-pro02a'],
#  'can animal slaughter cause pain': ['training-environment-ahwbsawhnbsf-pro01b'],
#  'can animals be morally responsible': ['training-environment-aelmmhbahr-con02b'],
#  'can animals have interests without language': ['training-environment-aelmmhbahr-con04b'],
#  'can animals learn sign language': ['training-environment-aelmmhbahr-pro04b'],
#  'can anorectic patient be force fed': ['training-health-mchdhgwhwff-pro02a'],
#  'can anorexia cause death': ['training-health-mchdhgwhwff-pro03b'],
#  'can anticyclical policy be applied internationally': ['training-international-ghbwg-pro02b'],
#  'can artist profit from copyright': ['training-digital-freedoms-iphwclcp-con01b'],
#  'can artist work part time': ['test-science-ascidfakhba-con04b'],
#  'can artists make money': ['training-digital-freedoms-iphwclcp-con03b'],
#  'can artists use copyright to their own advantage': ['training-digital-freedoms-iphwclcp-pro01a'],
#  'can assault weapons be banned': ['training-law-cphwusbaw-con01a'],
#  'can assisted suicide be a sin': ['test-health-dhpelhbass-con03a'],
#  'can autistic people avoid multiple vaccination': ['training-health-dhgamvs-pro03b'],
#  'can badger movement cause tuberculosis': ['training-environment-ahwcb-con02a'],
#  'can badgers be cull': ['training-environment-ahwcb-pro03b'],
#  'can because syria has been bombed in': ['validation-law-hrilppwhb-con01b'],
#  'can biometrics be used to transfer cash from a person to another': ['validation-international-aghwgcprp-pro02a'],
#  'can blasphemy be legal': ['training-free-speech-debate-nshbbhnpsb-con02a'],
#  'can blasphemy be universalised': ['training-free-speech-debate-nshbbhnpsb-con01b'],
#  'can bolivia grow cocaine': ['test-law-thgglcplgphw-con02a'],
#  'can border checkpoints be built?': ['validation-international-ahbwsuambwb-pro02b'],
#  'can boys be violent with toys': ['training-culture-vgcpiyhwrvv-con02a'],
#  'can boys get role models': ['training-sport-emgssghwfmdpa-pro03a'],
#  'can bringing a child into the world harm it': ['training-philosophy-olrfhwapgs-pro03b'],
#  'can britain accept the euro': ['test-politics-cpegiepgh-pro03a'],
#  'can bullfighting be illegal in spain': ['training-environment-assghbansb-pro03a'],
#  "can capital punishment be used for a killer's family": ['training-philosophy-oppelhsdp-pro01b'],
#  'can cash transfer be used to pay for school?': ['validation-international-aghwgcprp-pro04b'],
#  'can catalonia claim independence': ['training-international-eplgvhwar-con02a'],
#  'can celebrities influence the democratic system': ['test-politics-epvhbfsmsaop-pro02a'],
#  'can celibate priests work': ['training-religion-chwrrcptvc-con03a'],
#  'can censorship affect google': ['test-digital-freedoms-piidfaihbg-pro02a'],
#  'can chess be a sport for olympic games': ['training-sport-ohwico-pro02a'],
#  'can child stars be hired': ['test-culture-mmctyshwbcp-pro01b'],
#  'can children find information on themselves': ['training-health-oeghsshwpsst-pro03a'],
#  'can children go to school without adult supervision': ['training-law-cppfmyhwicc-pro05b'],
#  'can china be a cyber attack?': ['test-science-wsihwclscaaw-con02a'],
#  'can china be an example of good governance': ['test-politics-gvhwhnerse-pro04a'],
#  'can china lift the arms embargo': ['test-international-eghrhbeusli-pro05b'],
#  'can china maintain censorship': ['training-digital-freedoms-fehbwdsot-con01b'],
#  'can china use nuclear weapons': ['validation-politics-dhwdtnw-con04a'],
#  'can cigarette smoking be controlled': ['training-health-adhgphwfrs-pro01b'],
#  'can cigarettes and alcohol be used in advertisement': ['test-culture-mthbah-con03a'],
#  'can cigarettes be exported to india': ['training-health-adhgphwfrs-con04a'],
#  'can cities be used as subsidies': ['validation-economy-ecegthwspc-con03b'],
#  "can cloning be done if you can't have a child": ['training-health-hgfhwbhc-con03a'],
#  'can cluster bombs be used in warfare': ['test-politics-nlpdwhbusbuc-con01b'],
#  'can colonial power compensate for historical wrongs': ['test-international-aghbfcpspr-pro03a'],
#  "can companies sell people's personal information to third parties": ['test-digital-freedoms-phwnaccpdt-pro01a'],
#  'can competition affect the effectiveness of schools?': ['validation-economy-eehwpsstbm-pro04b'],
#  'can congress regulate non commercial activity': ['training-health-hghpghbus-con02b'],
#  'can congress use earmarks': ['test-politics-oapghwliva-pro01b'],
#  'can corporations use free speech in a democracy': ['training-free-speech-debate-esdbphwlfsr-pro01a'],
#  'can corporations use speech to gain political power': ['training-free-speech-debate-esdbphwlfsr-con01a'],
#  'can cosmetics be banned in china': ['test-culture-mmciahbans-con02b'],
#  ...}
